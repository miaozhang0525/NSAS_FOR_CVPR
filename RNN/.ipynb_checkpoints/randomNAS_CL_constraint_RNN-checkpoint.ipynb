# %%
import argparse
import os, sys, glob
import time
import math
import numpy as np
import torch
import logging
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from architect import Architect

from genotypes import PRIMITIVES, STEPS, CONCAT, Genotype

import genotypes

import copy
import gc

import data
import model_search as model

import inspect

from utils import batchify, get_batch, repackage_hidden, create_exp_dir, save_checkpoint

parser = argparse.ArgumentParser(description='PyTorch PennTreeBank/WikiText2 Language Model')
parser.add_argument('--data', type=str, default='../data/penn/',
                    help='location of the data corpus')
parser.add_argument('--emsize', type=int, default=300,
                    help='size of word embeddings')
parser.add_argument('--nhid', type=int, default=300,
                    help='number of hidden units per layer')
parser.add_argument('--nhidlast', type=int, default=300,
                    help='number of hidden units for the last rnn layer')
parser.add_argument('--lr', type=float, default=20,
                    help='initial learning rate')
parser.add_argument('--clip', type=float, default=0.25,
                    help='gradient clipping')
parser.add_argument('--epochs', type=int, default=300,
                    help='upper epoch limit')
parser.add_argument('--batch_size', type=int, default=64, metavar='N',
                    help='batch size')
parser.add_argument('--bptt', type=int, default=35,
                    help='sequence length')
parser.add_argument('--dropout', type=float, default=0.75,
                    help='dropout applied to layers (0 = no dropout)')
parser.add_argument('--dropouth', type=float, default=0.25,
                    help='dropout for hidden nodes in rnn layers (0 = no dropout)')
parser.add_argument('--dropoutx', type=float, default=0.75,
                    help='dropout for input nodes in rnn layers (0 = no dropout)')
parser.add_argument('--dropouti', type=float, default=0.2,
                    help='dropout for input embedding layers (0 = no dropout)')
parser.add_argument('--dropoute', type=float, default=0,
                    help='dropout to remove words from embedding layer (0 = no dropout)')
parser.add_argument('--seed', type=int, default=3,
                    help='random seed')
parser.add_argument('--nonmono', type=int, default=5,
                    help='random seed')
parser.add_argument('--cuda', action='store_false',
                    help='use CUDA')
parser.add_argument('--log-interval', type=int, default=50, metavar='N',
                    help='report interval')
parser.add_argument('--save', type=str,  default='EXP',
                    help='path to save the final model')
parser.add_argument('--alpha', type=float, default=0,
                    help='alpha L2 regularization on RNN activation (alpha = 0 means no regularization)')
parser.add_argument('--beta', type=float, default=1e-3,
                    help='beta slowness regularization applied on RNN activiation (beta = 0 means no regularization)')
parser.add_argument('--wdecay', type=float, default=5e-7,
                    help='weight decay applied to all weights')
parser.add_argument('--continue_train', action='store_true',
                    help='continue train from a checkpoint')
parser.add_argument('--small_batch_size', type=int, default=-1,
                    help='the batch size for computation. batch_size should be divisible by small_batch_size.\
                     In our implementation, we compute gradients with small_batch_size multiple times, and accumulate the gradients\
                     until batch_size is reached. An update step is then performed.')
parser.add_argument('--max_seq_len_delta', type=int, default=20,
                    help='max sequence length')
parser.add_argument('--single_gpu', default=True, action='store_false', 
                    help='use single GPU')
parser.add_argument('--gpu', type=int, default=0, help='GPU device to use')
parser.add_argument('--unrolled', action='store_true', default=False, help='use one-step unrolled validation loss')
parser.add_argument('--arch_wdecay', type=float, default=1e-3,
                    help='weight decay for the architecture encoding alpha')
parser.add_argument('--arch_lr', type=float, default=3e-3,
                    help='learning rate for the architecture encoding alpha')
args = parser.parse_args([])

if args.nhidlast < 0:
    args.nhidlast = args.emsize
if args.small_batch_size < 0:
    args.small_batch_size = args.batch_size

if not args.continue_train:
    args.save = 'search-{}-{}'.format(args.save, time.strftime("%Y%m%d-%H%M%S"))
    create_exp_dir(args.save, scripts_to_save=glob.glob('*.py'))

log_format = '%(asctime)s %(message)s'
logging.basicConfig(stream=sys.stdout, level=logging.INFO,
    format=log_format, datefmt='%m/%d %I:%M:%S %p')
fh = logging.FileHandler(os.path.join(args.save, 'log.txt'))
fh.setFormatter(logging.Formatter(log_format))
logging.getLogger().addHandler(fh)

# Set the random seed manually for reproducibility.
np.random.seed(args.seed)
torch.manual_seed(args.seed)
if torch.cuda.is_available():
    if not args.cuda:
        print("WARNING: You have a CUDA device, so you should probably run with --cuda")
    else:
        torch.cuda.set_device(args.gpu)
        cudnn.benchmark = True
        cudnn.enabled=True
        torch.cuda.manual_seed_all(args.seed)

corpus = data.Corpus(args.data)

eval_batch_size = 10
test_batch_size = 1

train_data = batchify(corpus.train, args.batch_size, args)
search_data = batchify(corpus.valid, args.batch_size, args)
val_data = batchify(corpus.valid, eval_batch_size, args)
test_data = batchify(corpus.test, test_batch_size, args)


ntokens = len(corpus.dictionary)
if args.continue_train:
    model = torch.load(os.path.join(args.save, 'model.pt'))
else:
    model = model.RNNModelSearch(ntokens, args.emsize, args.nhid, args.nhidlast, 
                       args.dropout, args.dropouth, args.dropoutx, args.dropouti, args.dropoute)

size = 0
for p in model.parameters():
    size += p.nelement()
logging.info('param size: {}'.format(size))
logging.info('initial genotype:')
logging.info(model.genotype())

if args.cuda:
    if args.single_gpu:
        parallel_model = model.cuda()
    else:
        parallel_model = nn.DataParallel(model, dim=1).cuda()
else:
    parallel_model = model
architect = Architect(parallel_model, args)

total_params = sum(x.data.nelement() for x in model.parameters())
logging.info('Args: {}'.format(args))
logging.info('Model total parameters: {}'.format(total_params))
# Out:
# Experiment dir : search-EXP-20191020-172455
# torch.Size([14524, 64])
# torch.Size([1152, 64])
# torch.Size([7376, 10])
# torch.Size([82430, 1])
# 10/20 05:25:03 PM param size: 4810000
# 10/20 05:25:03 PM initial genotype:
# 10/20 05:25:03 PM Genotype(recurrent=[('identity', 0), ('relu', 1), ('identity', 0), ('identity', 2), ('sigmoid', 4), ('tanh', 0), ('sigmoid', 1), ('identity', 6)], concat=range(1, 9))
# 10/20 05:25:03 PM Args: Namespace(alpha=0, arch_lr=0.003, arch_wdecay=0.001, batch_size=64, beta=0.001, bptt=35, clip=0.25, continue_train=False, cuda=True, data='../data/penn/', dropout=0.75, dropoute=0, dropouth=0.25, dropouti=0.2, dropoutx=0.75, emsize=300, epochs=300, gpu=0, log_interval=50, lr=20, max_seq_len_delta=20, nhid=300, nhidlast=300, nonmono=5, save='search-EXP-20191020-172455', seed=3, single_gpu=True, small_batch_size=64, unrolled=False, wdecay=5e-07)
# 10/20 05:25:03 PM Model total parameters: 4810000

# %%
def set_model_arch(model, arch):
    for rnn in model.rnns:
        rnn.genotype = arch
        
def set_model_weights(model, weights):
    model.weights = Variable(weights.cuda(), requires_grad=True)
    model._arch_parameters = [model.weights]
    

def random_arch_gene():
    n_nodes = genotypes.STEPS
    n_ops = len(genotypes.PRIMITIVES)
    arch_gene = []
    arch=[]
    for i in range(n_nodes):
        op = np.random.choice(range(1,n_ops))
        node_in = np.random.choice(range(i+1))
        arch_gene.append((op, node_in))
        arch.append((genotypes.PRIMITIVES[op], node_in))
    concat = range(1,9)
    genotype = genotypes.Genotype(recurrent=arch, concat=concat)
    return arch_gene,arch



def _genotype(weights):
    STEPS=8
    def _parse(probs):
        gene = []
        start = 0
        for i in range(STEPS):
            end = start + i + 1
            W = probs[start:end].copy()
            j = sorted(range(i + 1), key=lambda x: -max(W[x][k] for k in range(len(W[x])) if k != PRIMITIVES.index('none')))[0]
            k_best = None
            for k in range(len(W[j])):
                if k != PRIMITIVES.index('none'):
                    if k_best is None or W[j][k] > W[j][k_best]:
                        k_best = k
            gene.append((PRIMITIVES[k_best], j))
            start = end
        return gene

    gene = _parse(F.softmax(weights, dim=-1).data.cpu().numpy())
    genotype = Genotype(recurrent=gene, concat=range(STEPS+1)[-CONCAT:])
    return genotype



def _parse_gene(weights):
    STEPS=8
    gene = []
    start = 0
    weights_t=F.softmax(weights, dim=-1).data.cpu().numpy()
    for i in range(STEPS):
        end = start + i + 1
        W = weights_t[start:end].copy()
        j = sorted(range(i + 1), key=lambda x: -max(W[x][k] for k in range(len(W[x])) if k != PRIMITIVES.index('none')))[0]
        k_best = None
        for k in range(len(W[j])):
            if k != PRIMITIVES.index('none'):
                if k_best is None or W[j][k] > W[j][k_best]:
                    k_best = k
        gene.append((k_best, j))
        start = end
    return gene

from torch.autograd import Variable



def get_weights_from_arch(arch_gene):
    n_nodes = 8
    n_ops = 5
    weights = torch.zeros(sum([i+1 for i in range(n_nodes)]), n_ops)

    offset = 0
    for i in range(n_nodes):
        op = arch_gene[i][0]
        node_in = arch_gene[i][1]
        ind = offset + node_in
        weights[ind, op] = 5
        offset += (i+1)

    weights = torch.autograd.Variable(weights.cuda(), requires_grad=False)

    return weights

# %%
def random_arch_generate():
    num_ops = len(genotypes.PRIMITIVES)
    n_nodes = 4####model._step

    arch_gene = []
    for i in range(n_nodes):
        ops = np.random.choice(range(num_ops), 2)
        nodes_in_normal = np.random.choice(range(i+2), 2, replace=False)
        arch_gene.extend([(ops[0],nodes_in_normal[0]), (ops[1],nodes_in_normal[1])])
    return arch_gene  

def cal_arch_dis(arch1,arch2):#################small distance more similar
    dis=8
    n_nodes=4######genotypes.STEPS

    for i in range(n_nodes):
        if arch1[2*i]==arch2[2*i]:
            dis=dis-1
        elif arch1[2*i]==arch2[2*i+1]:
            dis=dis-1
        if arch1[2*i+1]==arch2[2*i+1]:
            dis=dis-1
        elif arch1[2*i+1]==arch2[2*i]:
            dis=dis-1                      
    dis=dis/8
    return dis 



def cal_diver_score(arch,archive):
    n=len(archive)
    dis=np.zeros(n)
    for i in range(n):
        dis[i]=cal_arch_dis(arch,archive[i])
        
    sort_dis=np.sort(dis)

    diver_score=np.mean(sort_dis[0:10])###################################k=10 for knn
    
    return diver_score
 

    
def diver_arch_generate(arch_archive):############randomly genrate architecture and get the best one
    ini_diver_score=0
    arch_g=random_arch_generate()
    for i in range(10):##################
        arch=random_arch_generate()         
        diver_score=cal_diver_score(arch,arch_archive)#########kernel metric, the samller the better
        if diver_score>ini_diver_score:
            arch_g=arch
            ini_diver_score=diver_score
            
    return arch_g


def diver_arch_replace(index,arch_archive,archive_recent):############randomly generate architecture to repalce
    arch_compar=arch_archive[index]
    a=np.arange(0,index)
    b=np.arange(index+1,len(arch_archive))
    index_remain=np.append(a,b)
    
    arch_archive_remain=[arch_archive[j] for j in index_remain]
    
    ini_diver_score=cal_diver_score(arch_compar,arch_archive_remain)
    for i in range(len(archive_recent)):######################################
        arch=archive_recent[i]
        diver_score=cal_diver_score(arch,arch_archive_remain)
        if diver_score>ini_diver_score:
            arch_compar=arch
            ini_diver_score=diver_score
            
    return arch_compar


def find_similar_arch(arch,archive):
    dis=np.zeros(len(archive))   
    
    for i in range(len(archive)):
        dis[i]=cal_arch_dis(arch,archive[i])################

    m=np.argsort(dis)
    index=m[0]
    
    return index



def arch_archive_update(arch_gene,arch_archive,archive_recent):
    store_num=8
    if len(arch_archive)==store_num:
        ind_arch_norm_replace=find_similar_arch(arch_gene,arch_archive)
        arch_archive[ind_arch_norm_replace]=diver_arch_replace(ind_arch_norm_replace,arch_archive,archive_recent)        
    else:
        normal_arch=diver_arch_generate(arch_archive)
        arch_archive.append(normal_arch)
    return arch_archive



def cal_loss_archive(arch_gene,arch_archive_new,model_save,input,target,criterion):
    loss_arch=0
    
    for i in range(np.int(len(arch_archive_new)/2)):
        w1=1-cal_arch_dis(arch_gene[0],arch_archive_new[2*i])##############################
        w2=1-cal_arch_dis(arch_gene[1],arch_archive_new[2*i+1])
        w=(w1+w2)/2
        model_save_save=copy.deepcopy(model_save)        
        model_weights=get_weights_from_arch(arch_archive_new[2*i:2*i+2])  
        model_save_save=set_model_weights(model_save_save,model_weights)
        
        logits = model_save_save(input)        
        loss=criterion(logits, target)
        loss_arch=w*(loss_arch+loss.item())
        del model_save_save
    loss_archive=(loss_arch*2)/len(arch_archive_new)
    del model_save
    return loss_archive

# %%
def set_model_arch(model, arch):
    for rnn in model.rnns:
        rnn.genotype = arch
        
def set_model_weights(model, weights):
    model.weights = Variable(weights.cuda(), requires_grad=True)
    model._arch_parameters = [model.weights]
    

def random_arch_gene():
    n_nodes = genotypes.STEPS
    n_ops = len(genotypes.PRIMITIVES)
    arch_gene = []
    arch=[]
    for i in range(n_nodes):
        op = np.random.choice(range(1,n_ops))
        node_in = np.random.choice(range(i+1))
        arch_gene.append((op, node_in))
        arch.append((genotypes.PRIMITIVES[op], node_in))
    concat = range(1,9)
    genotype = genotypes.Genotype(recurrent=arch, concat=concat)
    return arch_gene,arch



def _genotype(weights):
    STEPS=8
    def _parse(probs):
        gene = []
        start = 0
        for i in range(STEPS):
            end = start + i + 1
            W = probs[start:end].copy()
            j = sorted(range(i + 1), key=lambda x: -max(W[x][k] for k in range(len(W[x])) if k != PRIMITIVES.index('none')))[0]
            k_best = None
            for k in range(len(W[j])):
                if k != PRIMITIVES.index('none'):
                    if k_best is None or W[j][k] > W[j][k_best]:
                        k_best = k
            gene.append((PRIMITIVES[k_best], j))
            start = end
        return gene

    gene = _parse(F.softmax(weights, dim=-1).data.cpu().numpy())
    genotype = Genotype(recurrent=gene, concat=range(STEPS+1)[-CONCAT:])
    return genotype



def _parse_gene(weights):
    STEPS=8
    gene = []
    start = 0
    weights_t=F.softmax(weights, dim=-1).data.cpu().numpy()
    for i in range(STEPS):
        end = start + i + 1
        W = weights_t[start:end].copy()
        j = sorted(range(i + 1), key=lambda x: -max(W[x][k] for k in range(len(W[x])) if k != PRIMITIVES.index('none')))[0]
        k_best = None
        for k in range(len(W[j])):
            if k != PRIMITIVES.index('none'):
                if k_best is None or W[j][k] > W[j][k_best]:
                    k_best = k
        gene.append((k_best, j))
        start = end
    return gene

from torch.autograd import Variable

def get_arch_from_gene(arch_gene):
    n_nodes = 8
    n_ops = 5 
    arch=[]
    for i in range(n_nodes):
        op = arch_gene[i][0]
        node_in = arch_gene[i][1]    
        arch.append((genotypes.PRIMITIVES[op], node_in))
    concat = range(1,9)
    genotype = genotypes.Genotype(recurrent=arch, concat=concat)
    
    return genotype


def get_weights_from_arch(arch_gene):
    n_nodes = 8
    n_ops = 5
    weights = torch.zeros(sum([i+1 for i in range(n_nodes)]), n_ops)

    offset = 0
    for i in range(n_nodes):
        op = arch_gene[i][0]
        node_in = arch_gene[i][1]
        ind = offset + node_in
        weights[ind, op] = 5
        offset += (i+1)

    weights = torch.autograd.Variable(weights.cuda(), requires_grad=False)

    return weights




def evaluate(data_source, batch_size=10):
    # Turn on evaluation mode which disables dropout.
    model.eval()
    total_loss = 0
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(batch_size)
    for i in range(0, data_source.size(0) - 1, args.bptt):
        data, targets = get_batch(data_source, i, args, evaluation=True)
        targets = targets.view(-1)

        log_prob, hidden = parallel_model(data, hidden)
        loss = nn.functional.nll_loss(log_prob.view(-1, log_prob.size(2)), targets).data

        total_loss += loss * len(data)

        hidden = repackage_hidden(hidden)
    return total_loss[0] / len(data_source)

# %%
def train(model,epoch,arch_archive,archive_recent):
    assert args.batch_size % args.small_batch_size == 0, 'batch_size must be divisible by small_batch_size'
        
    #temp= opt.initial_temp * np.exp(-opt.anneal_rate * epoch)
    temp= 2.5 * np.exp(-0.00003* epoch)
    #temperature=torch.FloatTensor([temp])
    
    # Turn on training mode which enables dropout.
    total_loss = 0
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    hidden = [model.init_hidden(args.small_batch_size) for _ in range(args.batch_size // args.small_batch_size)]
    hidden_valid = [model.init_hidden(args.small_batch_size) for _ in range(args.batch_size // args.small_batch_size)]
    batch, i = 0, 0
    while i < train_data.size(0) - 1 - 1:
        bptt = args.bptt if np.random.random() < 0.95 else args.bptt / 2.
        # Prevent excessively small or negative sequence lengths
        # seq_len = max(5, int(np.random.normal(bptt, 5)))
        # # There's a very small chance that it could select a very long sequence length resulting in OOM
        # seq_len = min(seq_len, args.bptt + args.max_seq_len_delta)
        seq_len = int(bptt)

        lr2 = optimizer.param_groups[0]['lr']
        optimizer.param_groups[0]['lr'] = lr2 * seq_len / args.bptt
        model.train()

        data_valid, targets_valid = get_batch(search_data, i % (search_data.size(0) - 1), args)
        data, targets = get_batch(train_data, i, args, seq_len=seq_len)

        optimizer.zero_grad()

        start, end, s_id = 0, args.small_batch_size, 0
        while start < args.batch_size:
            
            weights_save=model.weights
            
            #arch,weights_gumble=sample_arch_from_weights(weights_save,temp)  
            #arch_gene=_parse_gene(weights_gumble)
            
            arch_gene,arch=random_arch_gene()                   
            weight_arch=get_weights_from_arch(arch_gene)
            
            set_model_arch(model, arch)
            set_model_weights(model, weight_arch)
            
            cur_data, cur_targets = data[:, start: end], targets[:, start: end].contiguous().view(-1)
            cur_data_valid, cur_targets_valid = data_valid[:, start: end], targets_valid[:, start: end].contiguous().view(-1)

            # Starting each batch, we detach the hidden state from how it was previously produced.
            # If we didn't, the model would try backpropagating all the way to start of the dataset.


            # assuming small_batch_size = batch_size so we don't accumulate gradients
            optimizer.zero_grad()
            hidden[s_id] = repackage_hidden(hidden[s_id])

            log_prob, hidden[s_id], rnn_hs, dropped_rnn_hs = parallel_model(cur_data, hidden[s_id], return_h=True)
            raw_loss = nn.functional.nll_loss(log_prob.view(-1, log_prob.size(2)), cur_targets)

            loss = raw_loss
            # Activiation Regularization
            if args.alpha > 0:
                loss = loss + sum(args.alpha * dropped_rnn_h.pow(2).mean() for dropped_rnn_h in dropped_rnn_hs[-1:])
            # Temporal Activation Regularization (slowness)
            loss = loss + sum(args.beta * (rnn_h[1:] - rnn_h[:-1]).pow(2).mean() for rnn_h in rnn_hs[-1:])
            loss *= args.small_batch_size / args.batch_size
            total_loss += raw_loss.data * args.small_batch_size / args.batch_size
            
            archive_recent.extend([arch_gene])
            archive_recent=archive_recent[-20:]
            
            arch_archive=arch_archive_update(arch_gene,arch_archive,archive_recent)
            
            loss_sr=0
            for arch in range(len(arch_archive)):
                model_save_r=copy.deepcopy(model)
                
                arch_gene_r=arch_archive[arch]     
                weight_arch_r=get_weights_from_arch(arch_gene_r)
                arch_r=get_arch_from_gene(arch_gene_r)


                set_model_arch(model_save_r, arch_r)
                set_model_weights(model_save_r, weight_arch_r)

                cur_data, cur_targets = data[:, start: end], targets[:, start: end].contiguous().view(-1)
                cur_data_valid, cur_targets_valid = data_valid[:, start: end], targets_valid[:, start: end].contiguous().view(-1)

                optimizer.zero_grad()
                hidden[s_id] = repackage_hidden(hidden[s_id])

                log_prob, hidden[s_id], rnn_hs, dropped_rnn_hs = parallel_model(cur_data, hidden[s_id], return_h=True)
                raw_loss = nn.functional.nll_loss(log_prob.view(-1, log_prob.size(2)), cur_targets)

                loss_r = raw_loss
                # Activiation Regularization
                if args.alpha > 0:
                    loss_r = loss_r + sum(args.alpha * dropped_rnn_h.pow(2).mean() for dropped_rnn_h in dropped_rnn_hs[-1:])
                # Temporal Activation Regularization (slowness)
                loss_r = loss_r + sum(args.beta * (rnn_h[1:] - rnn_h[:-1]).pow(2).mean() for rnn_h in rnn_hs[-1:])
                loss_r *= args.small_batch_size / args.batch_size
                
                loss_sr=loss_r+loss_r
            loss_sr=loss_sr/(len(arch_archive))
            
            loss_f=0.5*loss+0.5*loss_sr
       
            
            loss_f.backward()

            
            s_id += 1
            start = end
            end = start + args.small_batch_size

            gc.collect()

        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs.
        torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
        optimizer.step()

        # total_loss += raw_loss.data
        optimizer.param_groups[0]['lr'] = lr2
        if batch % args.log_interval == 0 and batch > 0:
            logging.info(parallel_model.genotype())
            #print(F.softmax(parallel_model.weights, dim=-1))
            cur_loss = total_loss[0] / args.log_interval
            elapsed = time.time() - start_time
            logging.info('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.2f} | ms/batch {:5.2f} | '
                    'loss {:5.2f} | ppl {:8.2f}'.format(
                epoch, batch, len(train_data) // args.bptt, optimizer.param_groups[0]['lr'],
                elapsed * 1000 / args.log_interval, cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()
        batch += 1
        i += seq_len

# %%
lr = args.lr
best_val_loss = []
stored_loss = 100000000

if args.continue_train:
    optimizer_state = torch.load(os.path.join(args.save, 'optimizer.pt'))
    if 't0' in optimizer_state['param_groups'][0]:
        optimizer = torch.optim.ASGD(model.parameters(), lr=args.lr, t0=0, lambd=0., weight_decay=args.wdecay)
    else:
        optimizer = torch.optim.SGD(model.parameters(), lr=args.lr, weight_decay=args.wdecay)
    optimizer.load_state_dict(optimizer_state)
else:
    optimizer = torch.optim.SGD(model.parameters(), lr=args.lr, weight_decay=args.wdecay)

# %%
stored_loss = 100000000
archive_recent=[]
arch_archive=[]
for epoch in range(1, args.epochs+1):
    epoch_start_time = time.time()
    train(model,epoch,arch_archive,archive_recent)

    val_loss = evaluate(val_data, eval_batch_size)
    logging.info('-' * 89)
    logging.info('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
            'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                       val_loss, math.exp(val_loss)))
    logging.info('-' * 89)

    if val_loss < stored_loss:
        save_checkpoint(model, optimizer, epoch, args.save)
        logging.info('Saving Normal!')
        stored_loss = val_loss

    best_val_loss.append(val_loss)
# Out:
# /data/mzhang3/anaconda3install/data/mzhang3/anaconda3install/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /data/mzhang3/anaconda3install/data/mzhang3/anaconda3install/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:1006: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /data/mzhang3/anaconda3install/data/mzhang3/anaconda3install/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /data/mzhang3/anaconda3install/data/mzhang3/anaconda3install/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /data/mzhang3/anaconda3install/data/mzhang3/anaconda3install/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:119: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# 10/20 05:27:04 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 0), ('tanh', 1), ('relu', 3), ('relu', 1), ('tanh', 3), ('sigmoid', 6), ('sigmoid', 3)], concat=range(1, 9))
# 10/20 05:27:04 PM | epoch   1 |    50/  414 batches | lr 20.00 | ms/batch 2399.94 | loss  9.66 | ppl 15616.63
# /data/mzhang3/anaconda3install/data/mzhang3/anaconda3install/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:127: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# 10/20 05:29:08 PM Genotype(recurrent=[('tanh', 0), ('tanh', 1), ('tanh', 0), ('sigmoid', 3), ('sigmoid', 4), ('sigmoid', 2), ('identity', 2), ('tanh', 1)], concat=range(1, 9))
# 10/20 05:29:08 PM | epoch   1 |   100/  414 batches | lr 20.00 | ms/batch 2483.54 | loss  9.18 | ppl  9700.95
# 10/20 05:31:13 PM Genotype(recurrent=[('identity', 0), ('identity', 1), ('identity', 2), ('tanh', 1), ('identity', 1), ('identity', 2), ('sigmoid', 3), ('relu', 4)], concat=range(1, 9))
# 10/20 05:31:13 PM | epoch   1 |   150/  414 batches | lr 20.00 | ms/batch 2513.22 | loss  9.01 | ppl  8187.99
# 10/20 05:33:19 PM Genotype(recurrent=[('relu', 0), ('relu', 0), ('relu', 0), ('sigmoid', 1), ('identity', 4), ('tanh', 2), ('relu', 0), ('sigmoid', 2)], concat=range(1, 9))
# 10/20 05:33:19 PM | epoch   1 |   200/  414 batches | lr 20.00 | ms/batch 2518.70 | loss  9.03 | ppl  8370.60
# 10/20 05:35:21 PM Genotype(recurrent=[('relu', 0), ('identity', 0), ('tanh', 2), ('sigmoid', 3), ('identity', 3), ('sigmoid', 5), ('relu', 4), ('sigmoid', 6)], concat=range(1, 9))
# 10/20 05:35:21 PM | epoch   1 |   250/  414 batches | lr 20.00 | ms/batch 2429.81 | loss  9.12 | ppl  9129.30
# 10/20 05:37:25 PM Genotype(recurrent=[('identity', 0), ('tanh', 1), ('tanh', 2), ('relu', 1), ('sigmoid', 1), ('relu', 1), ('tanh', 0), ('sigmoid', 0)], concat=range(1, 9))
# 10/20 05:37:25 PM | epoch   1 |   300/  414 batches | lr 20.00 | ms/batch 2474.42 | loss  8.69 | ppl  5953.99
# 10/20 05:39:28 PM Genotype(recurrent=[('identity', 0), ('sigmoid', 1), ('relu', 2), ('tanh', 0), ('relu', 1), ('identity', 3), ('tanh', 5), ('tanh', 2)], concat=range(1, 9))
# 10/20 05:39:28 PM | epoch   1 |   350/  414 batches | lr 20.00 | ms/batch 2459.83 | loss  8.85 | ppl  6954.69
# 10/20 05:41:28 PM Genotype(recurrent=[('relu', 0), ('relu', 1), ('sigmoid', 1), ('relu', 0), ('tanh', 0), ('identity', 1), ('identity', 2), ('relu', 7)], concat=range(1, 9))
# 10/20 05:41:28 PM | epoch   1 |   400/  414 batches | lr 20.00 | ms/batch 2415.46 | loss  8.94 | ppl  7644.45
# /data/mzhang3/DARTS/darts-master/rnn/utils.py:34: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   data = Variable(source[i:i+seq_len], volatile=evaluation)
# 10/20 05:43:05 PM -----------------------------------------------------------------------------------------
# 10/20 05:43:05 PM | end of epoch   1 | time: 1081.27s | valid loss  7.38 | valid ppl  1611.10
# 10/20 05:43:05 PM -----------------------------------------------------------------------------------------
# /data/mzhang3/anaconda3install/data/mzhang3/anaconda3install/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:120: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
# 10/20 05:43:05 PM Saving Normal!
# 10/20 05:45:10 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 1), ('tanh', 0), ('sigmoid', 2), ('relu', 4), ('relu', 1), ('identity', 4), ('relu', 0)], concat=range(1, 9))
# 10/20 05:45:10 PM | epoch   2 |    50/  414 batches | lr 20.00 | ms/batch 2507.58 | loss  9.21 | ppl 10019.42
# 10/20 05:47:13 PM Genotype(recurrent=[('relu', 0), ('relu', 0), ('relu', 1), ('tanh', 1), ('relu', 0), ('sigmoid', 5), ('relu', 3), ('tanh', 1)], concat=range(1, 9))
# 10/20 05:47:13 PM | epoch   2 |   100/  414 batches | lr 20.00 | ms/batch 2449.71 | loss  9.25 | ppl 10395.87
# 10/20 05:49:19 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 0), ('sigmoid', 0), ('sigmoid', 2), ('relu', 2), ('sigmoid', 2), ('sigmoid', 2), ('identity', 5)], concat=range(1, 9))
# 10/20 05:49:19 PM | epoch   2 |   150/  414 batches | lr 20.00 | ms/batch 2521.49 | loss  9.18 | ppl  9709.42
# 10/20 05:51:25 PM Genotype(recurrent=[('sigmoid', 0), ('identity', 0), ('identity', 2), ('identity', 0), ('identity', 2), ('sigmoid', 1), ('tanh', 2), ('relu', 1)], concat=range(1, 9))
# 10/20 05:51:25 PM | epoch   2 |   200/  414 batches | lr 20.00 | ms/batch 2517.72 | loss  9.48 | ppl 13072.96
# 10/20 05:53:32 PM Genotype(recurrent=[('tanh', 0), ('tanh', 1), ('sigmoid', 1), ('tanh', 0), ('identity', 0), ('sigmoid', 4), ('tanh', 0), ('relu', 6)], concat=range(1, 9))
# 10/20 05:53:32 PM | epoch   2 |   250/  414 batches | lr 20.00 | ms/batch 2537.75 | loss  9.45 | ppl 12766.76
# 10/20 05:55:39 PM Genotype(recurrent=[('identity', 0), ('tanh', 1), ('sigmoid', 1), ('relu', 1), ('relu', 1), ('identity', 0), ('relu', 1), ('identity', 3)], concat=range(1, 9))
# 10/20 05:55:39 PM | epoch   2 |   300/  414 batches | lr 20.00 | ms/batch 2537.90 | loss  9.34 | ppl 11357.64
# 10/20 05:57:38 PM Genotype(recurrent=[('identity', 0), ('sigmoid', 0), ('relu', 0), ('relu', 1), ('relu', 3), ('tanh', 0), ('tanh', 2), ('sigmoid', 6)], concat=range(1, 9))
# 10/20 05:57:38 PM | epoch   2 |   350/  414 batches | lr 20.00 | ms/batch 2389.55 | loss  9.23 | ppl 10244.97
# 10/20 05:59:43 PM Genotype(recurrent=[('relu', 0), ('identity', 1), ('identity', 1), ('identity', 3), ('sigmoid', 4), ('tanh', 1), ('tanh', 1), ('relu', 5)], concat=range(1, 9))
# 10/20 05:59:43 PM | epoch   2 |   400/  414 batches | lr 20.00 | ms/batch 2502.75 | loss  9.30 | ppl 10977.65
# 10/20 06:01:22 PM -----------------------------------------------------------------------------------------
# 10/20 06:01:22 PM | end of epoch   2 | time: 1096.70s | valid loss  7.35 | valid ppl  1563.73
# 10/20 06:01:22 PM -----------------------------------------------------------------------------------------
# 10/20 06:01:22 PM Saving Normal!
# 10/20 06:03:26 PM Genotype(recurrent=[('relu', 0), ('sigmoid', 1), ('relu', 2), ('sigmoid', 1), ('sigmoid', 3), ('identity', 1), ('identity', 3), ('sigmoid', 3)], concat=range(1, 9))
# 10/20 06:03:26 PM | epoch   3 |    50/  414 batches | lr 20.00 | ms/batch 2470.35 | loss  9.63 | ppl 15210.84
# 10/20 06:05:31 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 0), ('relu', 0), ('tanh', 2), ('tanh', 1), ('sigmoid', 1), ('sigmoid', 1), ('sigmoid', 0)], concat=range(1, 9))
# 10/20 06:05:31 PM | epoch   3 |   100/  414 batches | lr 20.00 | ms/batch 2513.62 | loss  9.70 | ppl 16312.94
# 10/20 06:07:36 PM Genotype(recurrent=[('relu', 0), ('relu', 0), ('sigmoid', 1), ('tanh', 1), ('relu', 3), ('relu', 5), ('sigmoid', 3), ('relu', 4)], concat=range(1, 9))
# 10/20 06:07:36 PM | epoch   3 |   150/  414 batches | lr 20.00 | ms/batch 2490.79 | loss  9.46 | ppl 12898.52
# 10/20 06:09:35 PM Genotype(recurrent=[('tanh', 0), ('identity', 0), ('identity', 1), ('sigmoid', 0), ('relu', 4), ('identity', 3), ('tanh', 6), ('tanh', 6)], concat=range(1, 9))
# 10/20 06:09:35 PM | epoch   3 |   200/  414 batches | lr 20.00 | ms/batch 2378.08 | loss  9.50 | ppl 13350.77
# 10/20 06:11:36 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 0), ('identity', 1), ('relu', 0), ('relu', 1), ('relu', 1), ('relu', 3), ('tanh', 5)], concat=range(1, 9))
# 10/20 06:11:36 PM | epoch   3 |   250/  414 batches | lr 20.00 | ms/batch 2428.31 | loss  9.66 | ppl 15683.64
# 10/20 06:13:40 PM Genotype(recurrent=[('identity', 0), ('relu', 1), ('sigmoid', 1), ('sigmoid', 1), ('relu', 1), ('identity', 4), ('relu', 5), ('relu', 7)], concat=range(1, 9))
# 10/20 06:13:40 PM | epoch   3 |   300/  414 batches | lr 20.00 | ms/batch 2470.21 | loss  9.56 | ppl 14167.02
# 10/20 06:15:42 PM Genotype(recurrent=[('sigmoid', 0), ('identity', 0), ('identity', 0), ('identity', 2), ('tanh', 3), ('sigmoid', 1), ('sigmoid', 3), ('sigmoid', 4)], concat=range(1, 9))
# 10/20 06:15:42 PM | epoch   3 |   350/  414 batches | lr 20.00 | ms/batch 2453.81 | loss  9.31 | ppl 11090.11
# 10/20 06:17:49 PM Genotype(recurrent=[('identity', 0), ('identity', 0), ('relu', 1), ('sigmoid', 1), ('relu', 4), ('relu', 0), ('tanh', 5), ('identity', 6)], concat=range(1, 9))
# 10/20 06:17:49 PM | epoch   3 |   400/  414 batches | lr 20.00 | ms/batch 2526.77 | loss  9.52 | ppl 13686.21
# 10/20 06:19:39 PM -----------------------------------------------------------------------------------------
# 10/20 06:19:39 PM | end of epoch   3 | time: 1096.76s | valid loss  7.16 | valid ppl  1284.26
# 10/20 06:19:39 PM -----------------------------------------------------------------------------------------
# 10/20 06:19:39 PM Saving Normal!
# 10/20 06:21:49 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 1), ('relu', 2), ('identity', 0), ('identity', 1), ('sigmoid', 2), ('tanh', 0), ('sigmoid', 7)], concat=range(1, 9))
# 10/20 06:21:49 PM | epoch   4 |    50/  414 batches | lr 20.00 | ms/batch 2593.90 | loss  9.31 | ppl 11099.87
# 10/20 06:23:54 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 0), ('identity', 2), ('sigmoid', 0), ('identity', 3), ('sigmoid', 2), ('identity', 3), ('relu', 7)], concat=range(1, 9))
# 10/20 06:23:54 PM | epoch   4 |   100/  414 batches | lr 20.00 | ms/batch 2504.59 | loss  9.01 | ppl  8209.32
# 10/20 06:26:00 PM Genotype(recurrent=[('relu', 0), ('tanh', 1), ('sigmoid', 0), ('relu', 0), ('relu', 2), ('sigmoid', 4), ('sigmoid', 5), ('relu', 2)], concat=range(1, 9))
# 10/20 06:26:00 PM | epoch   4 |   150/  414 batches | lr 20.00 | ms/batch 2512.08 | loss  8.82 | ppl  6764.29
# 10/20 06:28:07 PM Genotype(recurrent=[('relu', 0), ('tanh', 1), ('identity', 1), ('identity', 3), ('relu', 1), ('relu', 0), ('identity', 3), ('identity', 4)], concat=range(1, 9))
# 10/20 06:28:07 PM | epoch   4 |   200/  414 batches | lr 20.00 | ms/batch 2554.13 | loss  8.60 | ppl  5416.56
# 10/20 06:30:12 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 1), ('relu', 2), ('identity', 3), ('tanh', 0), ('tanh', 5), ('identity', 5), ('identity', 0)], concat=range(1, 9))
# 10/20 06:30:12 PM | epoch   4 |   250/  414 batches | lr 20.00 | ms/batch 2497.72 | loss  8.38 | ppl  4379.42
# 10/20 06:32:23 PM Genotype(recurrent=[('relu', 0), ('relu', 1), ('sigmoid', 2), ('tanh', 1), ('sigmoid', 1), ('sigmoid', 0), ('identity', 6), ('tanh', 2)], concat=range(1, 9))
# 10/20 06:32:23 PM | epoch   4 |   300/  414 batches | lr 20.00 | ms/batch 2619.38 | loss  8.23 | ppl  3736.88
# 10/20 06:34:30 PM Genotype(recurrent=[('relu', 0), ('identity', 1), ('tanh', 1), ('identity', 1), ('relu', 4), ('relu', 1), ('tanh', 0), ('identity', 1)], concat=range(1, 9))
# 10/20 06:34:30 PM | epoch   4 |   350/  414 batches | lr 20.00 | ms/batch 2535.19 | loss  8.05 | ppl  3146.38
# 10/20 06:36:37 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 0), ('relu', 0), ('tanh', 3), ('identity', 3), ('sigmoid', 2), ('relu', 6), ('relu', 3)], concat=range(1, 9))
# 10/20 06:36:37 PM | epoch   4 |   400/  414 batches | lr 20.00 | ms/batch 2548.64 | loss  7.80 | ppl  2449.30
# 10/20 06:38:16 PM -----------------------------------------------------------------------------------------
# 10/20 06:38:16 PM | end of epoch   4 | time: 1117.01s | valid loss  6.81 | valid ppl   904.61
# 10/20 06:38:16 PM -----------------------------------------------------------------------------------------
# 10/20 06:38:16 PM Saving Normal!
# 10/20 06:40:24 PM Genotype(recurrent=[('relu', 0), ('sigmoid', 0), ('relu', 1), ('tanh', 0), ('sigmoid', 0), ('sigmoid', 3), ('tanh', 2), ('sigmoid', 0)], concat=range(1, 9))
# 10/20 06:40:24 PM | epoch   5 |    50/  414 batches | lr 20.00 | ms/batch 2546.06 | loss  7.58 | ppl  1967.86
# 10/20 06:42:32 PM Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 2), ('sigmoid', 1), ('identity', 3), ('tanh', 1), ('identity', 6), ('tanh', 3)], concat=range(1, 9))
# 10/20 06:42:32 PM | epoch   5 |   100/  414 batches | lr 20.00 | ms/batch 2577.48 | loss  7.19 | ppl  1320.02
# 10/20 06:44:40 PM Genotype(recurrent=[('identity', 0), ('relu', 0), ('sigmoid', 2), ('relu', 3), ('identity', 0), ('tanh', 2), ('tanh', 2), ('relu', 3)], concat=range(1, 9))
# 10/20 06:44:40 PM | epoch   5 |   150/  414 batches | lr 20.00 | ms/batch 2552.82 | loss  6.84 | ppl   936.09
# 10/20 06:46:53 PM Genotype(recurrent=[('relu', 0), ('identity', 1), ('sigmoid', 0), ('tanh', 2), ('identity', 1), ('tanh', 5), ('identity', 5), ('relu', 1)], concat=range(1, 9))
# 10/20 06:46:53 PM | epoch   5 |   200/  414 batches | lr 20.00 | ms/batch 2658.42 | loss  6.68 | ppl   798.07
# 10/20 06:49:01 PM Genotype(recurrent=[('identity', 0), ('relu', 0), ('relu', 2), ('identity', 1), ('sigmoid', 2), ('tanh', 1), ('sigmoid', 6), ('identity', 7)], concat=range(1, 9))
# 10/20 06:49:01 PM | epoch   5 |   250/  414 batches | lr 20.00 | ms/batch 2552.21 | loss  6.50 | ppl   667.29
# 10/20 06:51:05 PM Genotype(recurrent=[('relu', 0), ('relu', 1), ('tanh', 1), ('relu', 3), ('relu', 4), ('tanh', 5), ('relu', 1), ('tanh', 7)], concat=range(1, 9))
# 10/20 06:51:05 PM | epoch   5 |   300/  414 batches | lr 20.00 | ms/batch 2487.96 | loss  6.35 | ppl   570.73
# 10/20 06:53:13 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 0), ('relu', 1), ('sigmoid', 2), ('relu', 4), ('tanh', 3), ('identity', 2), ('identity', 2)], concat=range(1, 9))
# 10/20 06:53:13 PM | epoch   5 |   350/  414 batches | lr 20.00 | ms/batch 2567.72 | loss  6.25 | ppl   516.81
# 10/20 06:55:20 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 0), ('sigmoid', 0), ('tanh', 0), ('identity', 1), ('relu', 0), ('identity', 6), ('sigmoid', 7)], concat=range(1, 9))
# 10/20 06:55:20 PM | epoch   5 |   400/  414 batches | lr 20.00 | ms/batch 2541.61 | loss  6.19 | ppl   489.22
# 10/20 06:56:52 PM -----------------------------------------------------------------------------------------
# 10/20 06:56:52 PM | end of epoch   5 | time: 1115.50s | valid loss  6.64 | valid ppl   767.67
# 10/20 06:56:52 PM -----------------------------------------------------------------------------------------
# 10/20 06:56:52 PM Saving Normal!
# 10/20 06:58:59 PM Genotype(recurrent=[('tanh', 0), ('relu', 1), ('tanh', 0), ('tanh', 0), ('relu', 0), ('identity', 5), ('relu', 1), ('identity', 5)], concat=range(1, 9))
# 10/20 06:58:59 PM | epoch   6 |    50/  414 batches | lr 20.00 | ms/batch 2540.11 | loss  6.25 | ppl   517.00
# 10/20 07:01:01 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 0), ('identity', 1), ('tanh', 1), ('sigmoid', 4), ('sigmoid', 4), ('tanh', 2), ('sigmoid', 3)], concat=range(1, 9))
# 10/20 07:01:01 PM | epoch   6 |   100/  414 batches | lr 20.00 | ms/batch 2438.05 | loss  6.06 | ppl   426.25
# 10/20 07:03:03 PM Genotype(recurrent=[('tanh', 0), ('tanh', 0), ('identity', 0), ('identity', 2), ('tanh', 3), ('identity', 0), ('relu', 6), ('relu', 4)], concat=range(1, 9))
# 10/20 07:03:03 PM | epoch   6 |   150/  414 batches | lr 20.00 | ms/batch 2432.01 | loss  5.99 | ppl   399.52
# 10/20 07:05:06 PM Genotype(recurrent=[('tanh', 0), ('relu', 0), ('tanh', 0), ('relu', 1), ('sigmoid', 0), ('relu', 4), ('identity', 3), ('relu', 1)], concat=range(1, 9))
# 10/20 07:05:06 PM | epoch   6 |   200/  414 batches | lr 20.00 | ms/batch 2464.50 | loss  5.95 | ppl   384.77
# 10/20 07:07:07 PM Genotype(recurrent=[('sigmoid', 0), ('tanh', 1), ('relu', 2), ('tanh', 0), ('identity', 2), ('tanh', 3), ('sigmoid', 5), ('relu', 7)], concat=range(1, 9))
# 10/20 07:07:07 PM | epoch   6 |   250/  414 batches | lr 20.00 | ms/batch 2415.95 | loss  5.99 | ppl   400.13
# 10/20 07:09:10 PM Genotype(recurrent=[('tanh', 0), ('identity', 1), ('sigmoid', 2), ('tanh', 1), ('tanh', 2), ('tanh', 2), ('tanh', 6), ('sigmoid', 0)], concat=range(1, 9))
# 10/20 07:09:10 PM | epoch   6 |   300/  414 batches | lr 20.00 | ms/batch 2474.42 | loss  5.96 | ppl   388.66
# 10/20 07:11:15 PM Genotype(recurrent=[('identity', 0), ('sigmoid', 0), ('relu', 1), ('identity', 0), ('tanh', 4), ('tanh', 2), ('identity', 6), ('tanh', 2)], concat=range(1, 9))
# 10/20 07:11:15 PM | epoch   6 |   350/  414 batches | lr 20.00 | ms/batch 2483.70 | loss  5.92 | ppl   372.76
# 10/20 07:13:21 PM Genotype(recurrent=[('identity', 0), ('tanh', 1), ('tanh', 1), ('identity', 0), ('sigmoid', 4), ('identity', 3), ('relu', 3), ('relu', 2)], concat=range(1, 9))
# 10/20 07:13:21 PM | epoch   6 |   400/  414 batches | lr 20.00 | ms/batch 2533.44 | loss  5.93 | ppl   377.28
# 10/20 07:15:04 PM -----------------------------------------------------------------------------------------
# 10/20 07:15:04 PM | end of epoch   6 | time: 1092.19s | valid loss  6.60 | valid ppl   738.36
# 10/20 07:15:04 PM -----------------------------------------------------------------------------------------
# 10/20 07:15:05 PM Saving Normal!
# 10/20 07:17:13 PM Genotype(recurrent=[('relu', 0), ('identity', 1), ('tanh', 2), ('relu', 2), ('relu', 1), ('sigmoid', 1), ('sigmoid', 3), ('sigmoid', 7)], concat=range(1, 9))
# 10/20 07:17:13 PM | epoch   7 |    50/  414 batches | lr 20.00 | ms/batch 2564.03 | loss  6.00 | ppl   404.09
# 10/20 07:19:19 PM Genotype(recurrent=[('tanh', 0), ('identity', 0), ('relu', 0), ('sigmoid', 3), ('identity', 4), ('identity', 2), ('relu', 3), ('identity', 1)], concat=range(1, 9))
# 10/20 07:19:19 PM | epoch   7 |   100/  414 batches | lr 20.00 | ms/batch 2532.58 | loss  5.86 | ppl   350.86
# 10/20 07:21:24 PM Genotype(recurrent=[('identity', 0), ('sigmoid', 0), ('identity', 1), ('identity', 1), ('relu', 1), ('sigmoid', 5), ('identity', 6), ('tanh', 6)], concat=range(1, 9))
# 10/20 07:21:24 PM | epoch   7 |   150/  414 batches | lr 20.00 | ms/batch 2484.24 | loss  5.79 | ppl   326.42
# 10/20 07:23:25 PM Genotype(recurrent=[('sigmoid', 0), ('tanh', 1), ('sigmoid', 1), ('tanh', 1), ('identity', 2), ('sigmoid', 5), ('relu', 5), ('relu', 6)], concat=range(1, 9))
# 10/20 07:23:25 PM | epoch   7 |   200/  414 batches | lr 20.00 | ms/batch 2423.06 | loss  5.75 | ppl   315.41
# 10/20 07:25:29 PM Genotype(recurrent=[('relu', 0), ('tanh', 1), ('relu', 2), ('relu', 3), ('relu', 1), ('relu', 5), ('relu', 2), ('identity', 0)], concat=range(1, 9))
# 10/20 07:25:29 PM | epoch   7 |   250/  414 batches | lr 20.00 | ms/batch 2482.93 | loss  5.82 | ppl   337.19
# 10/20 07:27:35 PM Genotype(recurrent=[('identity', 0), ('relu', 0), ('sigmoid', 1), ('sigmoid', 3), ('sigmoid', 2), ('sigmoid', 1), ('tanh', 3), ('tanh', 5)], concat=range(1, 9))
# 10/20 07:27:35 PM | epoch   7 |   300/  414 batches | lr 20.00 | ms/batch 2514.42 | loss  5.78 | ppl   322.62
# 10/20 07:29:40 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 1), ('relu', 0), ('sigmoid', 3), ('relu', 0), ('relu', 3), ('tanh', 3), ('sigmoid', 1)], concat=range(1, 9))
# 10/20 07:29:40 PM | epoch   7 |   350/  414 batches | lr 20.00 | ms/batch 2496.18 | loss  5.75 | ppl   313.76
# 10/20 07:31:45 PM Genotype(recurrent=[('relu', 0), ('sigmoid', 1), ('tanh', 0), ('tanh', 0), ('relu', 0), ('relu', 2), ('sigmoid', 0), ('tanh', 3)], concat=range(1, 9))
# 10/20 07:31:45 PM | epoch   7 |   400/  414 batches | lr 20.00 | ms/batch 2510.96 | loss  5.76 | ppl   318.29
# 10/20 07:33:16 PM -----------------------------------------------------------------------------------------
# 10/20 07:33:16 PM | end of epoch   7 | time: 1091.43s | valid loss  6.59 | valid ppl   725.14
# 10/20 07:33:16 PM -----------------------------------------------------------------------------------------
# 10/20 07:33:16 PM Saving Normal!
# 10/20 07:35:23 PM Genotype(recurrent=[('relu', 0), ('identity', 0), ('sigmoid', 2), ('identity', 2), ('relu', 0), ('identity', 4), ('tanh', 0), ('identity', 1)], concat=range(1, 9))
# 10/20 07:35:23 PM | epoch   8 |    50/  414 batches | lr 20.00 | ms/batch 2530.41 | loss  5.86 | ppl   351.86
# 10/20 07:37:29 PM Genotype(recurrent=[('sigmoid', 0), ('identity', 0), ('relu', 1), ('relu', 0), ('tanh', 2), ('relu', 4), ('tanh', 1), ('tanh', 3)], concat=range(1, 9))
# 10/20 07:37:29 PM | epoch   8 |   100/  414 batches | lr 20.00 | ms/batch 2529.29 | loss  5.72 | ppl   304.00
# 10/20 07:39:36 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 1), ('identity', 2), ('relu', 1), ('sigmoid', 4), ('tanh', 1), ('tanh', 1), ('tanh', 2)], concat=range(1, 9))
# 10/20 07:39:36 PM | epoch   8 |   150/  414 batches | lr 20.00 | ms/batch 2526.99 | loss  5.66 | ppl   287.15
# 10/20 07:41:38 PM Genotype(recurrent=[('relu', 0), ('identity', 1), ('sigmoid', 1), ('relu', 0), ('relu', 2), ('relu', 3), ('sigmoid', 2), ('tanh', 4)], concat=range(1, 9))
# 10/20 07:41:38 PM | epoch   8 |   200/  414 batches | lr 20.00 | ms/batch 2437.14 | loss  5.63 | ppl   279.74
# 10/20 07:43:40 PM Genotype(recurrent=[('tanh', 0), ('identity', 1), ('identity', 1), ('sigmoid', 2), ('relu', 3), ('tanh', 4), ('sigmoid', 1), ('sigmoid', 1)], concat=range(1, 9))
# 10/20 07:43:40 PM | epoch   8 |   250/  414 batches | lr 20.00 | ms/batch 2458.78 | loss  5.71 | ppl   300.93
# 10/20 07:45:46 PM Genotype(recurrent=[('relu', 0), ('relu', 0), ('identity', 0), ('sigmoid', 0), ('relu', 2), ('relu', 3), ('identity', 5), ('tanh', 3)], concat=range(1, 9))
# 10/20 07:45:46 PM | epoch   8 |   300/  414 batches | lr 20.00 | ms/batch 2507.67 | loss  5.67 | ppl   289.87
# 10/20 07:47:49 PM Genotype(recurrent=[('sigmoid', 0), ('identity', 1), ('relu', 0), ('identity', 2), ('relu', 0), ('sigmoid', 4), ('sigmoid', 6), ('tanh', 6)], concat=range(1, 9))
# 10/20 07:47:49 PM | epoch   8 |   350/  414 batches | lr 20.00 | ms/batch 2464.65 | loss  5.65 | ppl   285.00
# 10/20 07:49:52 PM Genotype(recurrent=[('tanh', 0), ('identity', 0), ('sigmoid', 2), ('sigmoid', 3), ('tanh', 4), ('identity', 5), ('identity', 2), ('identity', 5)], concat=range(1, 9))
# 10/20 07:49:52 PM | epoch   8 |   400/  414 batches | lr 20.00 | ms/batch 2463.58 | loss  5.67 | ppl   289.02
# 10/20 07:51:28 PM -----------------------------------------------------------------------------------------
# 10/20 07:51:28 PM | end of epoch   8 | time: 1092.01s | valid loss  6.58 | valid ppl   719.24
# 10/20 07:51:28 PM -----------------------------------------------------------------------------------------
# 10/20 07:51:29 PM Saving Normal!
# 10/20 07:53:37 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 1), ('tanh', 2), ('sigmoid', 1), ('relu', 3), ('sigmoid', 2), ('relu', 4), ('tanh', 5)], concat=range(1, 9))
# 10/20 07:53:37 PM | epoch   9 |    50/  414 batches | lr 20.00 | ms/batch 2570.46 | loss  5.76 | ppl   318.27
# 10/20 07:55:39 PM Genotype(recurrent=[('identity', 0), ('identity', 1), ('tanh', 1), ('tanh', 1), ('sigmoid', 3), ('sigmoid', 4), ('relu', 2), ('relu', 5)], concat=range(1, 9))
# 10/20 07:55:39 PM | epoch   9 |   100/  414 batches | lr 20.00 | ms/batch 2430.70 | loss  5.63 | ppl   278.81
# 10/20 07:57:44 PM Genotype(recurrent=[('relu', 0), ('tanh', 0), ('relu', 0), ('tanh', 3), ('sigmoid', 1), ('tanh', 2), ('sigmoid', 1), ('identity', 2)], concat=range(1, 9))
# 10/20 07:57:44 PM | epoch   9 |   150/  414 batches | lr 20.00 | ms/batch 2515.74 | loss  5.58 | ppl   266.25
# 10/20 07:59:47 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 1), ('identity', 2), ('tanh', 0), ('tanh', 0), ('sigmoid', 4), ('tanh', 0), ('tanh', 0)], concat=range(1, 9))
# 10/20 07:59:47 PM | epoch   9 |   200/  414 batches | lr 20.00 | ms/batch 2461.70 | loss  5.54 | ppl   254.64
# 10/20 08:01:54 PM Genotype(recurrent=[('relu', 0), ('tanh', 0), ('identity', 2), ('identity', 0), ('identity', 0), ('relu', 4), ('sigmoid', 5), ('sigmoid', 5)], concat=range(1, 9))
# 10/20 08:01:54 PM | epoch   9 |   250/  414 batches | lr 20.00 | ms/batch 2521.79 | loss  5.63 | ppl   277.85
# 10/20 08:03:58 PM Genotype(recurrent=[('relu', 0), ('identity', 1), ('sigmoid', 2), ('relu', 3), ('sigmoid', 1), ('tanh', 2), ('tanh', 1), ('identity', 4)], concat=range(1, 9))
# 10/20 08:03:58 PM | epoch   9 |   300/  414 batches | lr 20.00 | ms/batch 2497.88 | loss  5.60 | ppl   269.38
# 10/20 08:06:02 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 0), ('tanh', 1), ('relu', 1), ('identity', 0), ('sigmoid', 3), ('tanh', 4), ('sigmoid', 3)], concat=range(1, 9))
# 10/20 08:06:02 PM | epoch   9 |   350/  414 batches | lr 20.00 | ms/batch 2465.84 | loss  5.58 | ppl   264.54
# 10/20 08:08:04 PM Genotype(recurrent=[('identity', 0), ('identity', 0), ('identity', 0), ('sigmoid', 3), ('sigmoid', 0), ('relu', 3), ('identity', 3), ('relu', 7)], concat=range(1, 9))
# 10/20 08:08:04 PM | epoch   9 |   400/  414 batches | lr 20.00 | ms/batch 2453.79 | loss  5.60 | ppl   270.86
# 10/20 08:09:40 PM -----------------------------------------------------------------------------------------
# 10/20 08:09:40 PM | end of epoch   9 | time: 1090.98s | valid loss  6.57 | valid ppl   716.48
# 10/20 08:09:40 PM -----------------------------------------------------------------------------------------
# 10/20 08:09:40 PM Saving Normal!
# 10/20 08:11:43 PM Genotype(recurrent=[('identity', 0), ('identity', 0), ('identity', 2), ('tanh', 1), ('relu', 2), ('relu', 1), ('identity', 3), ('sigmoid', 5)], concat=range(1, 9))
# 10/20 08:11:43 PM | epoch  10 |    50/  414 batches | lr 20.00 | ms/batch 2467.57 | loss  5.70 | ppl   297.72
# 10/20 08:13:50 PM Genotype(recurrent=[('relu', 0), ('tanh', 1), ('relu', 1), ('relu', 1), ('relu', 3), ('identity', 5), ('relu', 2), ('sigmoid', 2)], concat=range(1, 9))
# 10/20 08:13:50 PM | epoch  10 |   100/  414 batches | lr 20.00 | ms/batch 2535.79 | loss  5.55 | ppl   257.99
# 10/20 08:15:56 PM Genotype(recurrent=[('sigmoid', 0), ('identity', 1), ('identity', 1), ('identity', 0), ('identity', 3), ('sigmoid', 1), ('identity', 5), ('relu', 0)], concat=range(1, 9))
# 10/20 08:15:56 PM | epoch  10 |   150/  414 batches | lr 20.00 | ms/batch 2508.40 | loss  5.51 | ppl   248.08
# 10/20 08:17:57 PM Genotype(recurrent=[('tanh', 0), ('relu', 0), ('relu', 2), ('identity', 0), ('identity', 4), ('tanh', 1), ('relu', 4), ('tanh', 1)], concat=range(1, 9))
# 10/20 08:17:57 PM | epoch  10 |   200/  414 batches | lr 20.00 | ms/batch 2428.72 | loss  5.47 | ppl   238.14
# 10/20 08:20:01 PM Genotype(recurrent=[('identity', 0), ('sigmoid', 0), ('relu', 1), ('tanh', 1), ('identity', 1), ('tanh', 2), ('tanh', 0), ('tanh', 5)], concat=range(1, 9))
# 10/20 08:20:01 PM | epoch  10 |   250/  414 batches | lr 20.00 | ms/batch 2480.05 | loss  5.57 | ppl   261.71
# 10/20 08:22:05 PM Genotype(recurrent=[('tanh', 0), ('identity', 0), ('tanh', 2), ('identity', 0), ('relu', 0), ('relu', 2), ('tanh', 6), ('relu', 5)], concat=range(1, 9))
# 10/20 08:22:05 PM | epoch  10 |   300/  414 batches | lr 20.00 | ms/batch 2481.56 | loss  5.54 | ppl   253.77
# 10/20 08:24:08 PM Genotype(recurrent=[('identity', 0), ('sigmoid', 0), ('sigmoid', 1), ('tanh', 2), ('tanh', 4), ('tanh', 0), ('sigmoid', 4), ('relu', 2)], concat=range(1, 9))
# 10/20 08:24:08 PM | epoch  10 |   350/  414 batches | lr 20.00 | ms/batch 2468.53 | loss  5.52 | ppl   248.40
# 10/20 08:26:10 PM Genotype(recurrent=[('relu', 0), ('relu', 1), ('identity', 0), ('sigmoid', 3), ('relu', 4), ('sigmoid', 2), ('identity', 2), ('sigmoid', 2)], concat=range(1, 9))
# 10/20 08:26:10 PM | epoch  10 |   400/  414 batches | lr 20.00 | ms/batch 2433.68 | loss  5.55 | ppl   258.06
# 10/20 08:27:54 PM -----------------------------------------------------------------------------------------
# 10/20 08:27:54 PM | end of epoch  10 | time: 1093.65s | valid loss  6.57 | valid ppl   714.64
# 10/20 08:27:54 PM -----------------------------------------------------------------------------------------
# 10/20 08:27:54 PM Saving Normal!
# 10/20 08:30:02 PM Genotype(recurrent=[('relu', 0), ('tanh', 1), ('identity', 1), ('identity', 0), ('relu', 2), ('identity', 3), ('tanh', 1), ('sigmoid', 4)], concat=range(1, 9))
# 10/20 08:30:02 PM | epoch  11 |    50/  414 batches | lr 20.00 | ms/batch 2551.28 | loss  5.64 | ppl   280.70
# 10/20 08:32:06 PM Genotype(recurrent=[('tanh', 0), ('relu', 1), ('identity', 2), ('sigmoid', 0), ('identity', 3), ('tanh', 3), ('sigmoid', 1), ('relu', 1)], concat=range(1, 9))
# 10/20 08:32:06 PM | epoch  11 |   100/  414 batches | lr 20.00 | ms/batch 2485.22 | loss  5.51 | ppl   246.85
# 10/20 08:34:11 PM Genotype(recurrent=[('identity', 0), ('relu', 0), ('tanh', 2), ('tanh', 3), ('tanh', 2), ('relu', 0), ('sigmoid', 3), ('sigmoid', 2)], concat=range(1, 9))
# 10/20 08:34:11 PM | epoch  11 |   150/  414 batches | lr 20.00 | ms/batch 2500.48 | loss  5.46 | ppl   234.35
# 10/20 08:36:11 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 1), ('relu', 0), ('identity', 2), ('tanh', 3), ('tanh', 4), ('relu', 0), ('sigmoid', 6)], concat=range(1, 9))
# 10/20 08:36:11 PM | epoch  11 |   200/  414 batches | lr 20.00 | ms/batch 2394.24 | loss  5.42 | ppl   225.86
# 10/20 08:38:13 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 0), ('tanh', 2), ('tanh', 0), ('relu', 3), ('tanh', 0), ('sigmoid', 2), ('identity', 5)], concat=range(1, 9))
# 10/20 08:38:13 PM | epoch  11 |   250/  414 batches | lr 20.00 | ms/batch 2456.27 | loss  5.51 | ppl   246.71
# 10/20 08:40:16 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 0), ('tanh', 1), ('tanh', 1), ('relu', 2), ('identity', 2), ('identity', 3), ('relu', 4)], concat=range(1, 9))
# 10/20 08:40:16 PM | epoch  11 |   300/  414 batches | lr 20.00 | ms/batch 2460.58 | loss  5.48 | ppl   240.95
# 10/20 08:42:21 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 1), ('sigmoid', 0), ('relu', 3), ('sigmoid', 2), ('identity', 2), ('identity', 0), ('sigmoid', 6)], concat=range(1, 9))
# 10/20 08:42:21 PM | epoch  11 |   350/  414 batches | lr 20.00 | ms/batch 2490.82 | loss  5.47 | ppl   237.91
# 10/20 08:44:26 PM Genotype(recurrent=[('tanh', 0), ('identity', 1), ('tanh', 2), ('tanh', 0), ('relu', 2), ('tanh', 4), ('sigmoid', 3), ('identity', 2)], concat=range(1, 9))
# 10/20 08:44:26 PM | epoch  11 |   400/  414 batches | lr 20.00 | ms/batch 2505.41 | loss  5.51 | ppl   247.29
# 10/20 08:46:11 PM -----------------------------------------------------------------------------------------
# 10/20 08:46:11 PM | end of epoch  11 | time: 1097.37s | valid loss  6.58 | valid ppl   719.23
# 10/20 08:46:11 PM -----------------------------------------------------------------------------------------
# 10/20 08:48:15 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 1), ('tanh', 1), ('tanh', 2), ('tanh', 0), ('tanh', 5), ('tanh', 0), ('sigmoid', 5)], concat=range(1, 9))
# 10/20 08:48:15 PM | epoch  12 |    50/  414 batches | lr 20.00 | ms/batch 2471.07 | loss  5.60 | ppl   270.88
# 10/20 08:50:20 PM Genotype(recurrent=[('identity', 0), ('relu', 1), ('relu', 0), ('sigmoid', 2), ('sigmoid', 0), ('relu', 3), ('tanh', 4), ('identity', 0)], concat=range(1, 9))
# 10/20 08:50:20 PM | epoch  12 |   100/  414 batches | lr 20.00 | ms/batch 2492.21 | loss  5.46 | ppl   234.88
# 10/20 08:52:24 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 0), ('relu', 2), ('relu', 3), ('sigmoid', 1), ('sigmoid', 4), ('tanh', 0), ('identity', 0)], concat=range(1, 9))
# 10/20 08:52:24 PM | epoch  12 |   150/  414 batches | lr 20.00 | ms/batch 2495.89 | loss  5.42 | ppl   226.78
# 10/20 08:54:30 PM Genotype(recurrent=[('relu', 0), ('sigmoid', 0), ('sigmoid', 0), ('relu', 3), ('relu', 0), ('identity', 5), ('tanh', 1), ('identity', 3)], concat=range(1, 9))
# 10/20 08:54:30 PM | epoch  12 |   200/  414 batches | lr 20.00 | ms/batch 2506.65 | loss  5.37 | ppl   214.94
# 10/20 08:56:31 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 0), ('identity', 2), ('relu', 2), ('identity', 4), ('relu', 2), ('sigmoid', 1), ('relu', 5)], concat=range(1, 9))
# 10/20 08:56:31 PM | epoch  12 |   250/  414 batches | lr 20.00 | ms/batch 2425.26 | loss  5.48 | ppl   239.35
# 10/20 08:58:33 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 1), ('identity', 1), ('relu', 0), ('identity', 1), ('identity', 4), ('relu', 6), ('relu', 2)], concat=range(1, 9))
# 10/20 08:58:33 PM | epoch  12 |   300/  414 batches | lr 20.00 | ms/batch 2433.08 | loss  5.45 | ppl   233.70
# 10/20 09:00:38 PM Genotype(recurrent=[('tanh', 0), ('tanh', 0), ('identity', 0), ('tanh', 0), ('relu', 4), ('relu', 5), ('tanh', 2), ('identity', 3)], concat=range(1, 9))
# 10/20 09:00:38 PM | epoch  12 |   350/  414 batches | lr 20.00 | ms/batch 2513.53 | loss  5.44 | ppl   230.57
# 10/20 09:02:45 PM Genotype(recurrent=[('tanh', 0), ('tanh', 0), ('sigmoid', 0), ('relu', 2), ('sigmoid', 4), ('tanh', 5), ('relu', 2), ('tanh', 1)], concat=range(1, 9))
# 10/20 09:02:45 PM | epoch  12 |   400/  414 batches | lr 20.00 | ms/batch 2529.40 | loss  5.47 | ppl   237.49
# 10/20 09:04:35 PM -----------------------------------------------------------------------------------------
# 10/20 09:04:35 PM | end of epoch  12 | time: 1103.30s | valid loss  6.57 | valid ppl   715.14
# 10/20 09:04:35 PM -----------------------------------------------------------------------------------------
# 10/20 09:06:46 PM Genotype(recurrent=[('sigmoid', 0), ('tanh', 1), ('identity', 0), ('tanh', 1), ('identity', 3), ('tanh', 1), ('sigmoid', 4), ('identity', 4)], concat=range(1, 9))
# 10/20 09:06:46 PM | epoch  13 |    50/  414 batches | lr 20.00 | ms/batch 2620.63 | loss  5.55 | ppl   258.24
# 10/20 09:08:52 PM Genotype(recurrent=[('identity', 0), ('tanh', 1), ('identity', 0), ('tanh', 1), ('sigmoid', 1), ('tanh', 3), ('tanh', 1), ('identity', 5)], concat=range(1, 9))
# 10/20 09:08:52 PM | epoch  13 |   100/  414 batches | lr 20.00 | ms/batch 2516.88 | loss  5.43 | ppl   228.76
# 10/20 09:10:55 PM Genotype(recurrent=[('sigmoid', 0), ('identity', 0), ('relu', 2), ('tanh', 0), ('identity', 2), ('relu', 3), ('tanh', 2), ('relu', 0)], concat=range(1, 9))
# 10/20 09:10:55 PM | epoch  13 |   150/  414 batches | lr 20.00 | ms/batch 2469.82 | loss  5.38 | ppl   217.11
# 10/20 09:13:07 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 0), ('sigmoid', 0), ('relu', 2), ('identity', 0), ('tanh', 3), ('identity', 1), ('sigmoid', 3)], concat=range(1, 9))
# 10/20 09:13:07 PM | epoch  13 |   200/  414 batches | lr 20.00 | ms/batch 2638.78 | loss  5.34 | ppl   208.66
# 10/20 09:15:23 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 1), ('identity', 0), ('relu', 3), ('identity', 1), ('sigmoid', 2), ('relu', 4), ('relu', 7)], concat=range(1, 9))
# 10/20 09:15:23 PM | epoch  13 |   250/  414 batches | lr 20.00 | ms/batch 2712.08 | loss  5.44 | ppl   230.56
# 10/20 09:17:30 PM Genotype(recurrent=[('relu', 0), ('relu', 1), ('sigmoid', 1), ('relu', 0), ('identity', 2), ('tanh', 5), ('relu', 5), ('identity', 0)], concat=range(1, 9))
# 10/20 09:17:30 PM | epoch  13 |   300/  414 batches | lr 20.00 | ms/batch 2546.30 | loss  5.42 | ppl   225.26
# 10/20 09:19:38 PM Genotype(recurrent=[('relu', 0), ('identity', 0), ('sigmoid', 2), ('tanh', 1), ('identity', 0), ('sigmoid', 5), ('identity', 2), ('identity', 0)], concat=range(1, 9))
# 10/20 09:19:38 PM | epoch  13 |   350/  414 batches | lr 20.00 | ms/batch 2564.41 | loss  5.41 | ppl   223.00
# 10/20 09:21:41 PM Genotype(recurrent=[('relu', 0), ('relu', 1), ('tanh', 1), ('relu', 3), ('tanh', 1), ('tanh', 1), ('relu', 2), ('identity', 4)], concat=range(1, 9))
# 10/20 09:21:41 PM | epoch  13 |   400/  414 batches | lr 20.00 | ms/batch 2461.42 | loss  5.45 | ppl   232.18
# 10/20 09:23:26 PM -----------------------------------------------------------------------------------------
# 10/20 09:23:26 PM | end of epoch  13 | time: 1131.80s | valid loss  6.57 | valid ppl   710.94
# 10/20 09:23:26 PM -----------------------------------------------------------------------------------------
# 10/20 09:23:27 PM Saving Normal!
# 10/20 09:25:35 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 0), ('tanh', 1), ('relu', 1), ('sigmoid', 4), ('relu', 4), ('relu', 2), ('tanh', 3)], concat=range(1, 9))
# 10/20 09:25:35 PM | epoch  14 |    50/  414 batches | lr 20.00 | ms/batch 2567.27 | loss  5.53 | ppl   251.36
# 10/20 09:27:44 PM Genotype(recurrent=[('relu', 0), ('identity', 1), ('identity', 1), ('relu', 3), ('identity', 1), ('identity', 4), ('sigmoid', 0), ('sigmoid', 4)], concat=range(1, 9))
# 10/20 09:27:44 PM | epoch  14 |   100/  414 batches | lr 20.00 | ms/batch 2569.26 | loss  5.39 | ppl   218.84
# 10/20 09:30:04 PM Genotype(recurrent=[('relu', 0), ('sigmoid', 0), ('tanh', 2), ('tanh', 0), ('tanh', 0), ('sigmoid', 3), ('tanh', 5), ('sigmoid', 3)], concat=range(1, 9))
# 10/20 09:30:04 PM | epoch  14 |   150/  414 batches | lr 20.00 | ms/batch 2817.68 | loss  5.35 | ppl   211.07
# 10/20 09:32:06 PM Genotype(recurrent=[('tanh', 0), ('tanh', 0), ('relu', 2), ('tanh', 1), ('sigmoid', 0), ('sigmoid', 2), ('identity', 3), ('identity', 1)], concat=range(1, 9))
# 10/20 09:32:06 PM | epoch  14 |   200/  414 batches | lr 20.00 | ms/batch 2440.47 | loss  5.31 | ppl   203.23
# 10/20 09:34:12 PM Genotype(recurrent=[('tanh', 0), ('relu', 1), ('sigmoid', 2), ('relu', 1), ('tanh', 0), ('tanh', 1), ('identity', 0), ('tanh', 2)], concat=range(1, 9))
# 10/20 09:34:12 PM | epoch  14 |   250/  414 batches | lr 20.00 | ms/batch 2505.20 | loss  5.41 | ppl   224.24
# 10/20 09:36:15 PM Genotype(recurrent=[('identity', 0), ('tanh', 1), ('tanh', 2), ('tanh', 2), ('sigmoid', 2), ('relu', 4), ('tanh', 1), ('tanh', 0)], concat=range(1, 9))
# 10/20 09:36:15 PM | epoch  14 |   300/  414 batches | lr 20.00 | ms/batch 2455.61 | loss  5.38 | ppl   217.60
# 10/20 09:38:27 PM Genotype(recurrent=[('tanh', 0), ('relu', 1), ('tanh', 2), ('relu', 0), ('relu', 1), ('tanh', 4), ('identity', 4), ('sigmoid', 5)], concat=range(1, 9))
# 10/20 09:38:27 PM | epoch  14 |   350/  414 batches | lr 20.00 | ms/batch 2654.89 | loss  5.39 | ppl   218.21
# 10/20 09:40:32 PM Genotype(recurrent=[('relu', 0), ('sigmoid', 0), ('sigmoid', 0), ('identity', 0), ('tanh', 2), ('identity', 3), ('tanh', 5), ('tanh', 0)], concat=range(1, 9))
# 10/20 09:40:32 PM | epoch  14 |   400/  414 batches | lr 20.00 | ms/batch 2501.10 | loss  5.41 | ppl   224.53
# 10/20 09:42:12 PM -----------------------------------------------------------------------------------------
# 10/20 09:42:12 PM | end of epoch  14 | time: 1125.28s | valid loss  6.56 | valid ppl   705.27
# 10/20 09:42:12 PM -----------------------------------------------------------------------------------------
# 10/20 09:42:12 PM Saving Normal!
# 10/20 09:44:20 PM Genotype(recurrent=[('identity', 0), ('relu', 1), ('identity', 2), ('relu', 0), ('relu', 1), ('tanh', 2), ('sigmoid', 2), ('identity', 1)], concat=range(1, 9))
# 10/20 09:44:20 PM | epoch  15 |    50/  414 batches | lr 20.00 | ms/batch 2556.97 | loss  5.50 | ppl   243.68
# 10/20 09:46:20 PM Genotype(recurrent=[('relu', 0), ('tanh', 0), ('sigmoid', 0), ('relu', 0), ('sigmoid', 4), ('tanh', 3), ('relu', 2), ('relu', 5)], concat=range(1, 9))
# 10/20 09:46:20 PM | epoch  15 |   100/  414 batches | lr 20.00 | ms/batch 2395.96 | loss  5.37 | ppl   214.94
# 10/20 09:48:26 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 0), ('relu', 2), ('tanh', 2), ('sigmoid', 3), ('tanh', 1), ('sigmoid', 5), ('sigmoid', 1)], concat=range(1, 9))
# 10/20 09:48:26 PM | epoch  15 |   150/  414 batches | lr 20.00 | ms/batch 2523.12 | loss  5.33 | ppl   206.43
# 10/20 09:50:33 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 0), ('sigmoid', 1), ('tanh', 2), ('tanh', 1), ('relu', 2), ('tanh', 6), ('sigmoid', 7)], concat=range(1, 9))
# 10/20 09:50:33 PM | epoch  15 |   200/  414 batches | lr 20.00 | ms/batch 2543.18 | loss  5.28 | ppl   196.99
# 10/20 09:52:35 PM Genotype(recurrent=[('relu', 0), ('identity', 1), ('relu', 0), ('sigmoid', 1), ('sigmoid', 2), ('relu', 0), ('relu', 0), ('tanh', 2)], concat=range(1, 9))
# 10/20 09:52:35 PM | epoch  15 |   250/  414 batches | lr 20.00 | ms/batch 2428.29 | loss  5.39 | ppl   220.00
# 10/20 09:54:37 PM Genotype(recurrent=[('relu', 0), ('identity', 1), ('identity', 1), ('sigmoid', 2), ('sigmoid', 4), ('identity', 5), ('sigmoid', 3), ('tanh', 3)], concat=range(1, 9))
# 10/20 09:54:37 PM | epoch  15 |   300/  414 batches | lr 20.00 | ms/batch 2445.45 | loss  5.37 | ppl   214.22
# 10/20 09:56:41 PM Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('identity', 0), ('sigmoid', 2), ('identity', 4), ('relu', 4), ('sigmoid', 4), ('tanh', 2)], concat=range(1, 9))
# 10/20 09:56:41 PM | epoch  15 |   350/  414 batches | lr 20.00 | ms/batch 2491.81 | loss  5.36 | ppl   213.03
# 10/20 09:58:50 PM Genotype(recurrent=[('relu', 0), ('sigmoid', 1), ('sigmoid', 2), ('relu', 1), ('identity', 1), ('relu', 4), ('tanh', 6), ('identity', 1)], concat=range(1, 9))
# 10/20 09:58:50 PM | epoch  15 |   400/  414 batches | lr 20.00 | ms/batch 2570.77 | loss  5.39 | ppl   219.98
# 10/20 10:00:37 PM -----------------------------------------------------------------------------------------
# 10/20 10:00:37 PM | end of epoch  15 | time: 1104.36s | valid loss  6.56 | valid ppl   704.54
# 10/20 10:00:37 PM -----------------------------------------------------------------------------------------
# 10/20 10:00:41 PM Saving Normal!
# 10/20 10:02:51 PM Genotype(recurrent=[('sigmoid', 0), ('tanh', 1), ('tanh', 0), ('relu', 0), ('sigmoid', 2), ('tanh', 3), ('identity', 6), ('relu', 1)], concat=range(1, 9))
# 10/20 10:02:51 PM | epoch  16 |    50/  414 batches | lr 20.00 | ms/batch 2600.41 | loss  5.47 | ppl   236.86
# 10/20 10:04:57 PM Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('relu', 0), ('identity', 1), ('relu', 3), ('sigmoid', 4), ('tanh', 2), ('tanh', 5)], concat=range(1, 9))
# 10/20 10:04:57 PM | epoch  16 |   100/  414 batches | lr 20.00 | ms/batch 2528.29 | loss  5.35 | ppl   209.98
# 10/20 10:07:05 PM Genotype(recurrent=[('relu', 0), ('identity', 0), ('relu', 2), ('sigmoid', 3), ('tanh', 1), ('tanh', 2), ('relu', 1), ('sigmoid', 3)], concat=range(1, 9))
# 10/20 10:07:05 PM | epoch  16 |   150/  414 batches | lr 20.00 | ms/batch 2559.55 | loss  5.31 | ppl   201.55
# 10/20 10:09:13 PM Genotype(recurrent=[('sigmoid', 0), ('identity', 1), ('relu', 0), ('identity', 2), ('relu', 4), ('relu', 5), ('tanh', 5), ('relu', 2)], concat=range(1, 9))
# 10/20 10:09:13 PM | epoch  16 |   200/  414 batches | lr 20.00 | ms/batch 2566.05 | loss  5.27 | ppl   193.47
# 10/20 10:11:22 PM Genotype(recurrent=[('tanh', 0), ('tanh', 0), ('relu', 2), ('relu', 3), ('identity', 4), ('identity', 1), ('sigmoid', 4), ('tanh', 2)], concat=range(1, 9))
# 10/20 10:11:22 PM | epoch  16 |   250/  414 batches | lr 20.00 | ms/batch 2565.93 | loss  5.36 | ppl   213.65
# 10/20 10:13:24 PM Genotype(recurrent=[('sigmoid', 0), ('identity', 1), ('sigmoid', 2), ('relu', 0), ('identity', 3), ('sigmoid', 1), ('relu', 2), ('sigmoid', 1)], concat=range(1, 9))
# 10/20 10:13:24 PM | epoch  16 |   300/  414 batches | lr 20.00 | ms/batch 2439.18 | loss  5.34 | ppl   208.87
# 10/20 10:15:24 PM Genotype(recurrent=[('relu', 0), ('identity', 0), ('relu', 0), ('identity', 2), ('tanh', 3), ('sigmoid', 1), ('tanh', 1), ('relu', 5)], concat=range(1, 9))
# 10/20 10:15:24 PM | epoch  16 |   350/  414 batches | lr 20.00 | ms/batch 2410.29 | loss  5.34 | ppl   208.01
# 10/20 10:17:29 PM Genotype(recurrent=[('relu', 0), ('tanh', 0), ('identity', 1), ('sigmoid', 2), ('sigmoid', 0), ('identity', 1), ('identity', 4), ('tanh', 6)], concat=range(1, 9))
# 10/20 10:17:29 PM | epoch  16 |   400/  414 batches | lr 20.00 | ms/batch 2493.18 | loss  5.37 | ppl   215.61
# 10/20 10:19:16 PM -----------------------------------------------------------------------------------------
# 10/20 10:19:16 PM | end of epoch  16 | time: 1115.44s | valid loss  6.56 | valid ppl   703.02
# 10/20 10:19:16 PM -----------------------------------------------------------------------------------------
# 10/20 10:19:16 PM Saving Normal!
# 10/20 10:21:24 PM Genotype(recurrent=[('sigmoid', 0), ('identity', 0), ('relu', 2), ('relu', 1), ('identity', 4), ('tanh', 5), ('identity', 1), ('relu', 7)], concat=range(1, 9))
# 10/20 10:21:24 PM | epoch  17 |    50/  414 batches | lr 20.00 | ms/batch 2552.43 | loss  5.45 | ppl   233.00
# 10/20 10:23:27 PM Genotype(recurrent=[('tanh', 0), ('tanh', 1), ('identity', 0), ('sigmoid', 1), ('identity', 0), ('tanh', 5), ('tanh', 4), ('relu', 2)], concat=range(1, 9))
# 10/20 10:23:27 PM | epoch  17 |   100/  414 batches | lr 20.00 | ms/batch 2459.50 | loss  5.34 | ppl   208.17
# 10/20 10:25:29 PM Genotype(recurrent=[('tanh', 0), ('relu', 1), ('identity', 0), ('relu', 1), ('identity', 4), ('sigmoid', 2), ('sigmoid', 0), ('sigmoid', 1)], concat=range(1, 9))
# 10/20 10:25:29 PM | epoch  17 |   150/  414 batches | lr 20.00 | ms/batch 2446.10 | loss  5.29 | ppl   197.44
# 10/20 10:27:33 PM Genotype(recurrent=[('identity', 0), ('identity', 0), ('identity', 2), ('tanh', 1), ('sigmoid', 4), ('tanh', 4), ('tanh', 6), ('identity', 5)], concat=range(1, 9))
# 10/20 10:27:33 PM | epoch  17 |   200/  414 batches | lr 20.00 | ms/batch 2481.60 | loss  5.24 | ppl   189.23
# 10/20 10:29:37 PM Genotype(recurrent=[('sigmoid', 0), ('identity', 1), ('sigmoid', 0), ('sigmoid', 3), ('relu', 3), ('identity', 0), ('relu', 4), ('tanh', 6)], concat=range(1, 9))
# 10/20 10:29:37 PM | epoch  17 |   250/  414 batches | lr 20.00 | ms/batch 2482.77 | loss  5.35 | ppl   211.36
# 10/20 10:31:40 PM Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('tanh', 2), ('identity', 3), ('identity', 1), ('relu', 1), ('identity', 0), ('tanh', 6)], concat=range(1, 9))
# 10/20 10:31:40 PM | epoch  17 |   300/  414 batches | lr 20.00 | ms/batch 2449.20 | loss  5.33 | ppl   205.50
# 10/20 10:33:42 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 0), ('relu', 1), ('sigmoid', 3), ('tanh', 1), ('identity', 2), ('identity', 6), ('sigmoid', 4)], concat=range(1, 9))
# 10/20 10:33:42 PM | epoch  17 |   350/  414 batches | lr 20.00 | ms/batch 2443.01 | loss  5.32 | ppl   203.78
# 10/20 10:35:46 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 1), ('tanh', 2), ('relu', 3), ('identity', 0), ('relu', 4), ('relu', 5), ('relu', 0)], concat=range(1, 9))
# 10/20 10:35:46 PM | epoch  17 |   400/  414 batches | lr 20.00 | ms/batch 2485.02 | loss  5.35 | ppl   210.76
# 10/20 10:37:26 PM -----------------------------------------------------------------------------------------
# 10/20 10:37:27 PM | end of epoch  17 | time: 1090.15s | valid loss  6.55 | valid ppl   702.38
# 10/20 10:37:27 PM -----------------------------------------------------------------------------------------
# 10/20 10:37:27 PM Saving Normal!
# 10/20 10:39:33 PM Genotype(recurrent=[('relu', 0), ('relu', 1), ('identity', 0), ('sigmoid', 2), ('tanh', 0), ('sigmoid', 4), ('sigmoid', 1), ('sigmoid', 5)], concat=range(1, 9))
# 10/20 10:39:33 PM | epoch  18 |    50/  414 batches | lr 20.00 | ms/batch 2518.85 | loss  5.44 | ppl   230.49
# 10/20 10:41:39 PM Genotype(recurrent=[('relu', 0), ('relu', 0), ('identity', 1), ('identity', 1), ('relu', 0), ('tanh', 3), ('identity', 5), ('identity', 7)], concat=range(1, 9))
# 10/20 10:41:39 PM | epoch  18 |   100/  414 batches | lr 20.00 | ms/batch 2517.77 | loss  5.31 | ppl   203.18
# 10/20 10:43:39 PM Genotype(recurrent=[('identity', 0), ('identity', 1), ('sigmoid', 1), ('sigmoid', 0), ('sigmoid', 0), ('identity', 3), ('sigmoid', 0), ('tanh', 0)], concat=range(1, 9))
# 10/20 10:43:39 PM | epoch  18 |   150/  414 batches | lr 20.00 | ms/batch 2408.21 | loss  5.27 | ppl   194.55
# 10/20 10:45:46 PM Genotype(recurrent=[('tanh', 0), ('identity', 0), ('identity', 0), ('sigmoid', 2), ('identity', 1), ('identity', 5), ('sigmoid', 0), ('identity', 3)], concat=range(1, 9))
# 10/20 10:45:46 PM | epoch  18 |   200/  414 batches | lr 20.00 | ms/batch 2534.79 | loss  5.23 | ppl   186.20
# 10/20 10:47:49 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 0), ('relu', 1), ('tanh', 2), ('tanh', 4), ('identity', 5), ('identity', 4), ('relu', 6)], concat=range(1, 9))
# ...
# 10/24 12:15:12 PM -----------------------------------------------------------------------------------------
# 10/24 12:15:12 PM | end of epoch 294 | time: 1128.14s | valid loss  6.50 | valid ppl   663.55
# 10/24 12:15:12 PM -----------------------------------------------------------------------------------------
# 10/24 12:17:24 PM Genotype(recurrent=[('identity', 0), ('tanh', 0), ('identity', 2), ('identity', 0), ('identity', 1), ('relu', 2), ('sigmoid', 2), ('relu', 2)], concat=range(1, 9))
# 10/24 12:17:25 PM | epoch 295 |    50/  414 batches | lr 20.00 | ms/batch 2648.96 | loss  5.05 | ppl   156.64
# 10/24 12:19:36 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 0), ('sigmoid', 1), ('relu', 3), ('sigmoid', 2), ('tanh', 0), ('relu', 0), ('tanh', 3)], concat=range(1, 9))
# 10/24 12:19:36 PM | epoch 295 |   100/  414 batches | lr 20.00 | ms/batch 2636.84 | loss  4.96 | ppl   141.93
# 10/24 12:21:50 PM Genotype(recurrent=[('identity', 0), ('sigmoid', 0), ('sigmoid', 2), ('sigmoid', 1), ('tanh', 4), ('sigmoid', 0), ('sigmoid', 5), ('identity', 4)], concat=range(1, 9))
# 10/24 12:21:50 PM | epoch 295 |   150/  414 batches | lr 20.00 | ms/batch 2682.58 | loss  4.90 | ppl   134.87
# 10/24 12:23:58 PM Genotype(recurrent=[('identity', 0), ('sigmoid', 1), ('relu', 1), ('tanh', 0), ('tanh', 2), ('tanh', 5), ('tanh', 6), ('sigmoid', 6)], concat=range(1, 9))
# 10/24 12:23:58 PM | epoch 295 |   200/  414 batches | lr 20.00 | ms/batch 2556.19 | loss  4.84 | ppl   126.55
# 10/24 12:26:03 PM Genotype(recurrent=[('tanh', 0), ('relu', 1), ('relu', 1), ('relu', 0), ('sigmoid', 1), ('relu', 5), ('tanh', 6), ('relu', 0)], concat=range(1, 9))
# 10/24 12:26:03 PM | epoch 295 |   250/  414 batches | lr 20.00 | ms/batch 2491.53 | loss  4.97 | ppl   144.09
# 10/24 12:28:14 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 0), ('tanh', 1), ('sigmoid', 0), ('tanh', 4), ('relu', 5), ('sigmoid', 5), ('relu', 2)], concat=range(1, 9))
# 10/24 12:28:14 PM | epoch 295 |   300/  414 batches | lr 20.00 | ms/batch 2615.88 | loss  4.95 | ppl   141.43
# 10/24 12:30:20 PM Genotype(recurrent=[('identity', 0), ('identity', 1), ('identity', 1), ('tanh', 0), ('relu', 1), ('tanh', 4), ('relu', 3), ('relu', 1)], concat=range(1, 9))
# 10/24 12:30:20 PM | epoch 295 |   350/  414 batches | lr 20.00 | ms/batch 2525.10 | loss  4.97 | ppl   143.64
# 10/24 12:32:27 PM Genotype(recurrent=[('sigmoid', 0), ('identity', 0), ('relu', 2), ('tanh', 0), ('sigmoid', 3), ('sigmoid', 3), ('identity', 1), ('relu', 4)], concat=range(1, 9))
# 10/24 12:32:27 PM | epoch 295 |   400/  414 batches | lr 20.00 | ms/batch 2549.20 | loss  5.00 | ppl   148.10
# 10/24 12:34:09 PM -----------------------------------------------------------------------------------------
# 10/24 12:34:09 PM | end of epoch 295 | time: 1136.81s | valid loss  6.50 | valid ppl   668.01
# 10/24 12:34:09 PM -----------------------------------------------------------------------------------------
# 10/24 12:36:24 PM Genotype(recurrent=[('identity', 0), ('identity', 0), ('identity', 1), ('relu', 3), ('identity', 2), ('sigmoid', 0), ('tanh', 2), ('sigmoid', 0)], concat=range(1, 9))
# 10/24 12:36:24 PM | epoch 296 |    50/  414 batches | lr 20.00 | ms/batch 2703.91 | loss  5.06 | ppl   157.64
# 10/24 12:38:32 PM Genotype(recurrent=[('identity', 0), ('tanh', 1), ('tanh', 2), ('identity', 0), ('tanh', 2), ('sigmoid', 2), ('tanh', 5), ('identity', 5)], concat=range(1, 9))
# 10/24 12:38:32 PM | epoch 296 |   100/  414 batches | lr 20.00 | ms/batch 2560.83 | loss  4.95 | ppl   141.38
# 10/24 12:40:39 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 0), ('sigmoid', 2), ('relu', 3), ('relu', 4), ('sigmoid', 5), ('relu', 5), ('tanh', 6)], concat=range(1, 9))
# 10/24 12:40:39 PM | epoch 296 |   150/  414 batches | lr 20.00 | ms/batch 2529.74 | loss  4.90 | ppl   134.65
# 10/24 12:42:48 PM Genotype(recurrent=[('sigmoid', 0), ('identity', 0), ('tanh', 0), ('relu', 0), ('tanh', 1), ('relu', 3), ('sigmoid', 4), ('identity', 1)], concat=range(1, 9))
# 10/24 12:42:48 PM | epoch 296 |   200/  414 batches | lr 20.00 | ms/batch 2595.79 | loss  4.84 | ppl   126.48
# 10/24 12:44:50 PM Genotype(recurrent=[('identity', 0), ('tanh', 0), ('sigmoid', 0), ('identity', 2), ('sigmoid', 2), ('sigmoid', 3), ('identity', 3), ('tanh', 5)], concat=range(1, 9))
# 10/24 12:44:50 PM | epoch 296 |   250/  414 batches | lr 20.00 | ms/batch 2427.88 | loss  4.97 | ppl   143.99
# 10/24 12:46:55 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 1), ('sigmoid', 0), ('sigmoid', 1), ('identity', 0), ('tanh', 0), ('identity', 3), ('sigmoid', 6)], concat=range(1, 9))
# 10/24 12:46:55 PM | epoch 296 |   300/  414 batches | lr 20.00 | ms/batch 2512.84 | loss  4.94 | ppl   139.95
# 10/24 12:49:01 PM Genotype(recurrent=[('relu', 0), ('sigmoid', 1), ('relu', 0), ('identity', 2), ('sigmoid', 3), ('relu', 2), ('tanh', 4), ('identity', 6)], concat=range(1, 9))
# 10/24 12:49:01 PM | epoch 296 |   350/  414 batches | lr 20.00 | ms/batch 2514.77 | loss  4.95 | ppl   141.51
# 10/24 12:51:06 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 1), ('sigmoid', 2), ('identity', 2), ('relu', 0), ('identity', 1), ('sigmoid', 3), ('relu', 0)], concat=range(1, 9))
# 10/24 12:51:06 PM | epoch 296 |   400/  414 batches | lr 20.00 | ms/batch 2502.67 | loss  4.99 | ppl   146.51
# 10/24 12:52:54 PM -----------------------------------------------------------------------------------------
# 10/24 12:52:54 PM | end of epoch 296 | time: 1124.70s | valid loss  6.50 | valid ppl   663.31
# 10/24 12:52:54 PM -----------------------------------------------------------------------------------------
# 10/24 12:55:08 PM Genotype(recurrent=[('relu', 0), ('identity', 1), ('sigmoid', 1), ('identity', 1), ('sigmoid', 4), ('identity', 4), ('relu', 5), ('sigmoid', 4)], concat=range(1, 9))
# 10/24 12:55:08 PM | epoch 297 |    50/  414 batches | lr 20.00 | ms/batch 2686.54 | loss  5.05 | ppl   155.36
# 10/24 12:57:23 PM Genotype(recurrent=[('identity', 0), ('sigmoid', 1), ('tanh', 1), ('sigmoid', 0), ('relu', 0), ('identity', 5), ('sigmoid', 3), ('tanh', 6)], concat=range(1, 9))
# 10/24 12:57:23 PM | epoch 297 |   100/  414 batches | lr 20.00 | ms/batch 2702.50 | loss  4.96 | ppl   142.02
# 10/24 12:59:40 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 1), ('identity', 1), ('relu', 0), ('tanh', 1), ('sigmoid', 3), ('relu', 3), ('tanh', 1)], concat=range(1, 9))
# 10/24 12:59:40 PM | epoch 297 |   150/  414 batches | lr 20.00 | ms/batch 2743.40 | loss  4.90 | ppl   134.86
# 10/24 01:01:45 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 1), ('sigmoid', 0), ('identity', 2), ('tanh', 4), ('identity', 0), ('identity', 1), ('sigmoid', 4)], concat=range(1, 9))
# 10/24 01:01:45 PM | epoch 297 |   200/  414 batches | lr 20.00 | ms/batch 2497.39 | loss  4.85 | ppl   127.41
# 10/24 01:03:49 PM Genotype(recurrent=[('tanh', 0), ('identity', 0), ('sigmoid', 2), ('tanh', 0), ('tanh', 3), ('tanh', 3), ('identity', 5), ('sigmoid', 2)], concat=range(1, 9))
# 10/24 01:03:49 PM | epoch 297 |   250/  414 batches | lr 20.00 | ms/batch 2482.82 | loss  4.96 | ppl   143.30
# 10/24 01:05:55 PM Genotype(recurrent=[('tanh', 0), ('identity', 1), ('identity', 2), ('relu', 0), ('identity', 2), ('relu', 3), ('identity', 3), ('tanh', 4)], concat=range(1, 9))
# 10/24 01:05:55 PM | epoch 297 |   300/  414 batches | lr 20.00 | ms/batch 2525.49 | loss  4.94 | ppl   140.17
# 10/24 01:08:00 PM Genotype(recurrent=[('relu', 0), ('relu', 0), ('identity', 0), ('relu', 0), ('sigmoid', 4), ('relu', 4), ('relu', 5), ('tanh', 4)], concat=range(1, 9))
# 10/24 01:08:00 PM | epoch 297 |   350/  414 batches | lr 20.00 | ms/batch 2496.96 | loss  4.95 | ppl   141.88
# 10/24 01:10:09 PM Genotype(recurrent=[('relu', 0), ('relu', 1), ('identity', 0), ('identity', 1), ('tanh', 3), ('identity', 1), ('identity', 2), ('relu', 5)], concat=range(1, 9))
# 10/24 01:10:09 PM | epoch 297 |   400/  414 batches | lr 20.00 | ms/batch 2580.43 | loss  5.00 | ppl   148.00
# 10/24 01:11:52 PM -----------------------------------------------------------------------------------------
# 10/24 01:11:52 PM | end of epoch 297 | time: 1138.09s | valid loss  6.50 | valid ppl   663.52
# 10/24 01:11:52 PM -----------------------------------------------------------------------------------------
# 10/24 01:13:58 PM Genotype(recurrent=[('sigmoid', 0), ('tanh', 0), ('sigmoid', 0), ('tanh', 0), ('tanh', 0), ('identity', 3), ('tanh', 2), ('identity', 6)], concat=range(1, 9))
# 10/24 01:13:58 PM | epoch 298 |    50/  414 batches | lr 20.00 | ms/batch 2529.57 | loss  5.06 | ppl   158.21
# 10/24 01:16:05 PM Genotype(recurrent=[('tanh', 0), ('identity', 0), ('relu', 1), ('sigmoid', 0), ('identity', 3), ('tanh', 5), ('tanh', 1), ('sigmoid', 6)], concat=range(1, 9))
# 10/24 01:16:05 PM | epoch 298 |   100/  414 batches | lr 20.00 | ms/batch 2539.69 | loss  4.95 | ppl   141.13
# 10/24 01:18:11 PM Genotype(recurrent=[('tanh', 0), ('relu', 1), ('identity', 0), ('identity', 3), ('identity', 3), ('identity', 2), ('tanh', 2), ('identity', 6)], concat=range(1, 9))
# 10/24 01:18:11 PM | epoch 298 |   150/  414 batches | lr 20.00 | ms/batch 2514.91 | loss  4.92 | ppl   136.50
# 10/24 01:20:14 PM Genotype(recurrent=[('identity', 0), ('tanh', 1), ('tanh', 1), ('identity', 1), ('identity', 1), ('sigmoid', 4), ('relu', 1), ('relu', 1)], concat=range(1, 9))
# 10/24 01:20:14 PM | epoch 298 |   200/  414 batches | lr 20.00 | ms/batch 2465.06 | loss  4.82 | ppl   124.54
# 10/24 01:22:18 PM Genotype(recurrent=[('identity', 0), ('identity', 1), ('sigmoid', 2), ('relu', 0), ('tanh', 2), ('identity', 2), ('tanh', 1), ('relu', 5)], concat=range(1, 9))
# 10/24 01:22:18 PM | epoch 298 |   250/  414 batches | lr 20.00 | ms/batch 2467.89 | loss  4.97 | ppl   143.52
# 10/24 01:24:29 PM Genotype(recurrent=[('identity', 0), ('identity', 0), ('identity', 1), ('identity', 0), ('tanh', 4), ('identity', 1), ('identity', 2), ('tanh', 3)], concat=range(1, 9))
# 10/24 01:24:29 PM | epoch 298 |   300/  414 batches | lr 20.00 | ms/batch 2623.50 | loss  4.94 | ppl   140.04
# 10/24 01:26:38 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 0), ('sigmoid', 0), ('relu', 1), ('identity', 4), ('identity', 3), ('sigmoid', 1), ('tanh', 3)], concat=range(1, 9))
# 10/24 01:26:38 PM | epoch 298 |   350/  414 batches | lr 20.00 | ms/batch 2579.43 | loss  4.96 | ppl   143.03
# 10/24 01:28:46 PM Genotype(recurrent=[('tanh', 0), ('sigmoid', 1), ('identity', 1), ('relu', 0), ('relu', 2), ('relu', 5), ('identity', 0), ('relu', 3)], concat=range(1, 9))
# 10/24 01:28:46 PM | epoch 298 |   400/  414 batches | lr 20.00 | ms/batch 2571.76 | loss  4.99 | ppl   147.34
# 10/24 01:30:38 PM -----------------------------------------------------------------------------------------
# 10/24 01:30:38 PM | end of epoch 298 | time: 1126.74s | valid loss  6.49 | valid ppl   660.90
# 10/24 01:30:38 PM -----------------------------------------------------------------------------------------
# 10/24 01:32:48 PM Genotype(recurrent=[('relu', 0), ('identity', 0), ('relu', 2), ('sigmoid', 2), ('tanh', 0), ('relu', 3), ('relu', 4), ('relu', 7)], concat=range(1, 9))
# 10/24 01:32:48 PM | epoch 299 |    50/  414 batches | lr 20.00 | ms/batch 2600.54 | loss  5.05 | ppl   156.18
# 10/24 01:34:57 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 0), ('sigmoid', 2), ('sigmoid', 1), ('tanh', 2), ('sigmoid', 0), ('tanh', 0), ('identity', 1)], concat=range(1, 9))
# 10/24 01:34:57 PM | epoch 299 |   100/  414 batches | lr 20.00 | ms/batch 2569.87 | loss  4.95 | ppl   141.14
# 10/24 01:37:09 PM Genotype(recurrent=[('relu', 0), ('relu', 0), ('sigmoid', 0), ('identity', 0), ('sigmoid', 2), ('identity', 5), ('relu', 6), ('tanh', 6)], concat=range(1, 9))
# 10/24 01:37:09 PM | epoch 299 |   150/  414 batches | lr 20.00 | ms/batch 2641.18 | loss  4.91 | ppl   135.65
# 10/24 01:39:17 PM Genotype(recurrent=[('tanh', 0), ('tanh', 1), ('identity', 2), ('sigmoid', 0), ('tanh', 3), ('tanh', 2), ('relu', 4), ('relu', 3)], concat=range(1, 9))
# 10/24 01:39:17 PM | epoch 299 |   200/  414 batches | lr 20.00 | ms/batch 2563.76 | loss  4.85 | ppl   127.19
# 10/24 01:41:27 PM Genotype(recurrent=[('tanh', 0), ('relu', 0), ('identity', 1), ('relu', 3), ('identity', 4), ('identity', 1), ('sigmoid', 1), ('relu', 0)], concat=range(1, 9))
# 10/24 01:41:27 PM | epoch 299 |   250/  414 batches | lr 20.00 | ms/batch 2591.97 | loss  4.97 | ppl   143.74
# 10/24 01:43:30 PM Genotype(recurrent=[('identity', 0), ('relu', 0), ('relu', 0), ('identity', 2), ('relu', 4), ('relu', 0), ('relu', 6), ('relu', 0)], concat=range(1, 9))
# 10/24 01:43:30 PM | epoch 299 |   300/  414 batches | lr 20.00 | ms/batch 2462.63 | loss  4.95 | ppl   140.87
# 10/24 01:45:39 PM Genotype(recurrent=[('relu', 0), ('sigmoid', 1), ('sigmoid', 1), ('relu', 2), ('relu', 4), ('identity', 2), ('tanh', 0), ('relu', 1)], concat=range(1, 9))
# 10/24 01:45:39 PM | epoch 299 |   350/  414 batches | lr 20.00 | ms/batch 2579.07 | loss  4.95 | ppl   140.74
# 10/24 01:47:47 PM Genotype(recurrent=[('sigmoid', 0), ('sigmoid', 1), ('tanh', 1), ('tanh', 1), ('tanh', 0), ('identity', 5), ('relu', 2), ('tanh', 0)], concat=range(1, 9))
# 10/24 01:47:47 PM | epoch 299 |   400/  414 batches | lr 20.00 | ms/batch 2556.79 | loss  5.00 | ppl   147.85
# 10/24 01:49:34 PM -----------------------------------------------------------------------------------------
# 10/24 01:49:34 PM | end of epoch 299 | time: 1135.92s | valid loss  6.50 | valid ppl   662.53
# 10/24 01:49:34 PM -----------------------------------------------------------------------------------------
# 10/24 01:51:48 PM Genotype(recurrent=[('relu', 0), ('tanh', 1), ('identity', 2), ('identity', 0), ('tanh', 3), ('sigmoid', 5), ('tanh', 6), ('identity', 4)], concat=range(1, 9))
# 10/24 01:51:48 PM | epoch 300 |    50/  414 batches | lr 20.00 | ms/batch 2663.83 | loss  5.06 | ppl   158.12
# 10/24 01:53:53 PM Genotype(recurrent=[('tanh', 0), ('tanh', 0), ('identity', 2), ('tanh', 2), ('sigmoid', 3), ('tanh', 2), ('tanh', 6), ('sigmoid', 3)], concat=range(1, 9))
# 10/24 01:53:53 PM | epoch 300 |   100/  414 batches | lr 20.00 | ms/batch 2507.42 | loss  4.96 | ppl   141.98
# 10/24 01:56:00 PM Genotype(recurrent=[('tanh', 0), ('relu', 1), ('relu', 1), ('identity', 0), ('sigmoid', 2), ('tanh', 4), ('identity', 5), ('identity', 0)], concat=range(1, 9))
# 10/24 01:56:00 PM | epoch 300 |   150/  414 batches | lr 20.00 | ms/batch 2540.26 | loss  4.91 | ppl   136.21
# 10/24 01:58:04 PM Genotype(recurrent=[('relu', 0), ('relu', 0), ('identity', 1), ('tanh', 2), ('tanh', 3), ('relu', 4), ('tanh', 4), ('identity', 3)], concat=range(1, 9))
# 10/24 01:58:04 PM | epoch 300 |   200/  414 batches | lr 20.00 | ms/batch 2477.96 | loss  4.84 | ppl   126.98
# 10/24 02:00:15 PM Genotype(recurrent=[('relu', 0), ('tanh', 1), ('sigmoid', 0), ('sigmoid', 2), ('tanh', 2), ('tanh', 4), ('sigmoid', 0), ('identity', 1)], concat=range(1, 9))
# 10/24 02:00:15 PM | epoch 300 |   250/  414 batches | lr 20.00 | ms/batch 2623.67 | loss  4.98 | ppl   144.97
# 10/24 02:02:21 PM Genotype(recurrent=[('sigmoid', 0), ('relu', 1), ('relu', 0), ('tanh', 2), ('tanh', 2), ('tanh', 1), ('relu', 6), ('sigmoid', 4)], concat=range(1, 9))
# 10/24 02:02:21 PM | epoch 300 |   300/  414 batches | lr 20.00 | ms/batch 2526.19 | loss  4.95 | ppl   141.30
# 10/24 02:04:31 PM Genotype(recurrent=[('sigmoid', 0), ('tanh', 1), ('relu', 2), ('sigmoid', 2), ('sigmoid', 2), ('sigmoid', 4), ('sigmoid', 4), ('relu', 6)], concat=range(1, 9))
# 10/24 02:04:31 PM | epoch 300 |   350/  414 batches | lr 20.00 | ms/batch 2599.16 | loss  4.96 | ppl   142.65
# 10/24 02:06:34 PM Genotype(recurrent=[('identity', 0), ('tanh', 0), ('relu', 2), ('identity', 1), ('sigmoid', 0), ('relu', 0), ('tanh', 0), ('tanh', 3)], concat=range(1, 9))
# 10/24 02:06:34 PM | epoch 300 |   400/  414 batches | lr 20.00 | ms/batch 2461.61 | loss  5.00 | ppl   148.82
# 10/24 02:08:23 PM -----------------------------------------------------------------------------------------
# 10/24 02:08:23 PM | end of epoch 300 | time: 1128.53s | valid loss  6.50 | valid ppl   663.43
# 10/24 02:08:23 PM -----------------------------------------------------------------------------------------

# %%
model.genotype()
# Out:
# Genotype(recurrent=[('identity', 0), ('identity', 0), ('identity', 2), ('identity', 2), ('tanh', 1), ('relu', 5), ('relu', 6), ('identity', 3)], concat=range(1, 9))

# %%
get_arch_from_gene
